# %% [markdown]
# # STRONG CORRELATIONS LOCALIZER
# This script aims to find in which groups can we locate the different strongly correlated MGE-ARG pairs that we have obtained in the correlation study script. It depends on having ran the copy per seq and the detection study scripts before hand.
#
# Having gotten here, we have a series of .json files in which different information is condensed
#
# - arg_per_typology: it contains all the different ARG sequences that have amplified, deglosed by sample typology
# - mge_per_typology: same idea, but with MGE sequences
# - shared_different_seqs_per_place: a sort of addendum to the two first lists, it contains the sequences (both ARG and MGE, it needs a little bit of trimming) that were shared by both plastics and control but have a significant greater NCN in plastics (there were none that did so in control samples)
# - correlations_per_typology: la piece de la resistance, a list with all the strongly correlated MGE-ARG pairs (neatly formatted) and in which sample type can we find them
#
# So, the idea is simple: take the list of strongly correlated MGEs and find them within the maremagnum of amplified thingys, and locate in which sample typology they are. Then, do the same for the ARGs. The most interesting part will be to see how many of the strongly correlated MGEs are exclusive to a typology, and whether the exclusive ARGs of said typology are also strongly correlated.
#
# A neat bow can be put to everything if those MGE/ARGs were also strongly correlated to exclusive ASVs. But, that will wait.

# %%
import json
import pandas as pd

# %%
with open("../data/resistome_data/metadata/arg_per_typology.json") as json_file:
    arg_per_typology = json.load(json_file)
with open("../data/resistome_data/metadata/mge_per_typology.json") as json_file:
    mge_per_typology = json.load(json_file)
with open("../data/resistome_data/metadata/shared_different_seqs_per_place.json") as json_file:
    diff_seqs = json.load(json_file)
with open("../data/resistome_data/metadata/correlations_per_typology.json") as json_file:
    corrs = json.load(json_file)

# %%
# create a new dictionary with the same structure as the ones with every typology separated and this time, filter the MGEs found within to only keep those that are strongly correlated
# Also, keep count of where it's been found
everything_mge = {} 
for category in mge_per_typology.keys():
    for mge in mge_per_typology[category]:
        for corr_typology in corrs.keys():
            for correlated_mge in corrs[corr_typology]:
                if mge == correlated_mge: 
                    if category not in everything_mge.keys():
                        everything_mge[category] = []
                        everything_mge[category].append((mge, corr_typology))
                        #everything[category].append(corr_typology)
                        continue
                    else:
                        everything_mge[category].append((mge, corr_typology))
                        #everything[category].append(mge)
                        #everything[category].append(corr_typology)

everything_mge
# Out:
# {'pe_sw': [('IS91', 'plastic_ex_corrs'),
#   ('dfrA1', 'plastic_ex_corrs'),
#   ('cro', 'plastic_ex_corrs'),
#   ('IS200a', 'plastic_ex_corrs'),
#   ('tnpAc', 'plastic_ex_corrs'),
#   ('tnpAb', 'plastic_ex_corrs'),
#   ('TN5403', 'plastic_ex_corrs'),
#   ('IncW_trwAB', 'plastic_ex_corrs'),
#   ('IS6100', 'plastic_ex_corrs'),
#   ('EAE_05855', 'plastic_ex_corrs'),
#   ('dfrA12', 'plastic_ex_corrs'),
#   ('ISPps1-pseud', 'plastic_ex_corrs'),
#   ('Tn3', 'plastic_ex_corrs')],
#  'ps_ew': [('IS26', 'plastic_ex_corrs'),
#   ('IS26', 'control_ex_corrs'),
#   ('IS26', 'shared_corrs')],
#  'es_pw': [('mobA', 'plastic_ex_corrs')],
#  'pes_w': [('IS630', 'plastic_ex_corrs'),
#   ('ISEcp1', 'plastic_ex_corrs'),
#   ('IS613', 'plastic_ex_corrs'),
#   ('IS21-ISAs29', 'plastic_ex_corrs'),
#   ('fabK', 'plastic_ex_corrs'),
#   ('fabK', 'control_ex_corrs'),
#   ('fabK', 'shared_corrs'),
#   ('IS1247', 'plastic_ex_corrs'),
#   ('orf39-IS26', 'plastic_ex_corrs'),
#   ('IS256', 'plastic_ex_corrs'),
#   ('ARR-3', 'plastic_ex_corrs'),
#   ('ARR-3', 'control_ex_corrs'),
#   ('ARR-3', 'shared_corrs'),
#   ('bacA', 'plastic_ex_corrs'),
#   ('IncN_rep', 'plastic_ex_corrs'),
#   ('IncN_rep', 'control_ex_corrs'),
#   ('IncN_rep', 'shared_corrs'),
#   ('tnpAf', 'plastic_ex_corrs'),
#   ('tnpAf', 'control_ex_corrs'),
#   ('tnpAf', 'shared_corrs'),
#   ('IS6/257', 'plastic_ex_corrs'),
#   ('IS200b', 'plastic_ex_corrs'),
#   ('TN5', 'plastic_ex_corrs'),
#   ('TN5', 'control_ex_corrs'),
#   ('TN5', 'shared_corrs'),
#   ('int1-a-marko', 'plastic_ex_corrs'),
#   ('int1-a-marko', 'control_ex_corrs'),
#   ('int1-a-marko', 'shared_corrs'),
#   ('ISSm2-Xanthob', 'plastic_ex_corrs'),
#   ('ISSm2-Xanthob', 'control_ex_corrs'),
#   ('ISEfm1-Entero', 'plastic_ex_corrs'),
#   ('ISEfm1-Entero', 'control_ex_corrs'),
#   ('ISEfm1-Entero', 'shared_corrs'),
#   ('IncQ_oriT', 'plastic_ex_corrs'),
#   ('IncQ_oriT', 'control_ex_corrs'),
#   ('IncQ_oriT', 'shared_corrs'),
#   ('IS1133', 'plastic_ex_corrs'),
#   ('tnpAa', 'plastic_ex_corrs'),
#   ('IS3', 'plastic_ex_corrs'),
#   ('ISCR1', 'plastic_ex_corrs'),
#   ('tra-A', 'plastic_ex_corrs'),
#   ('traN', 'plastic_ex_corrs'),
#   ('lncF_FIC', 'plastic_ex_corrs'),
#   ('fosb', 'plastic_ex_corrs'),
#   ('fosb', 'control_ex_corrs'),
#   ('fosb', 'shared_corrs'),
#   ('Arr2', 'plastic_ex_corrs'),
#   ('Arr2', 'control_ex_corrs'),
#   ('Arr2', 'shared_corrs'),
#   ('tnpAg', 'plastic_ex_corrs'),
#   ('tnpAg', 'control_ex_corrs'),
#   ('tnpAg', 'shared_corrs'),
#   ('IncI1_repI1', 'plastic_ex_corrs'),
#   ('Tp614', 'plastic_ex_corrs'),
#   ('mcr-1', 'plastic_ex_corrs'),
#   ('fosX', 'plastic_ex_corrs'),
#   ('IncHI2-smr0018', 'plastic_ex_corrs'),
#   ('IncHI2-smr0018', 'control_ex_corrs'),
#   ('IncHI2-smr0018', 'shared_corrs'),
#   ('trfa', 'plastic_ex_corrs'),
#   ('ISAba3-Acineto', 'plastic_ex_corrs'),
#   ('ISAba3-Acineto', 'control_ex_corrs'),
#   ('ISAba3-Acineto', 'shared_corrs'),
#   ('nisB', 'plastic_ex_corrs')],
#  'pesw': [('intI1F165_clinical', 'plastic_ex_corrs'),
#   ('orf37-IS26', 'plastic_ex_corrs')]}

# %% [markdown]
# Before continuing, it seems that all but ISSm2-Xanthob are always present in plastics and, if they're not, they are present in plastics, control and shared both at once. ISSm2-Xanthob only has plastic and control. I'm going to take a look to have an idea of what could be going on under each MGE

# %%
print("######## ISSm2-Xanthob ########")
print(corrs["plastic_ex_corrs"]["ISSm2-Xanthob"])
print(corrs["control_ex_corrs"]["ISSm2-Xanthob"])
print("")
print("######## ISAba3-Acineto ########")
print(corrs["plastic_ex_corrs"]["ISAba3-Acineto"])
print(corrs["control_ex_corrs"]["ISAba3-Acineto"])
print(corrs["shared_corrs"]["ISAba3-Acineto"])
# Out:
# ######## ISSm2-Xanthob ########
# ['qnrB-bob_resign', 'mphA', 'pica', "aac(6')-Ib", 'blaPSE']
# ['catA1', 'cefa_qacelta', 'tetS', 'QnrS1_S3_S5', 'qnrS2', 'lsa(C)', 'aadD', 'erm(B)', 'ermX', 'vanRB', 'blaOCH', 'erm(Q)', 'pikR2', 'lnu(F)', 'catA3', 'dfrA10', 'apmA', 'blaCTX-M', 'QnrB4', 'catB9', 'vanC2/vanC3', 'vgaB', 'aph_viii', 'merA-marko', 'terW', 'vanTG', 'bla-SME', 'tetX', 'blaHERA', 'sul2', 'aadA_99', 'blaIMI', 'msr(A)', 'vanXA', 'qacF/Ha', 'vga(A)LC', 'aadA5', 'aadE', 'tetH', 'vat(E)', 'erm(F)b', 'cfxA', 'ampC/blaDHA', 'blaGES', 'aac(6)-is_iu_ix', 'tetPB', 'blaLEN', 'erm(F)a', 'dfra21', 'tcrB', 'vanWB', 'mefA', 'vanA', 'ant6-ib', 'ermA/ermTR', 'erm(A)', 'catP', 'ermY', 'erm(D)', 'bl1acc', 'vanRD', 'aac(6)-iw', 'lnuB', 'mtrD', 'tet39', 'aadA2b', 'sulA/folP']
#
# ######## ISAba3-Acineto ########
# ['strB', 'vanSB', 'mdth', 'cmlA1', 'aac(3)-Xab', 'lsa(C)', 'QnrVC1_VC3_VC6', 'sugE', 'aadA10', 'dfrA10', 'aac(6)-ij', 'vgaB', 'aph_viii', 'terW', 'aac(3)-xaa', 'bla-L1', 'aadA17', 'aac(6)-iv_ih', "aac(6')-II", 'vatB', 'arsA', 'blaPAO/PDC', 'aac(6)-im', 'mexA', 'tetPB', 'blaLEN', 'carB', 'mef(B)', 'blaCMY', 'erm(D)', 'blaSHV-11', 'dfrK', 'cmx(A)', 'tetS', 'NDM new', 'msr(C)', 'ermX', 'ArmA', 'erm(42)', 'apmA', 'ttgA', 'ampC', 'ampC/blaDHA', 'blaIMIR', 'dfrA27', 'catP', 'mtrD', 'mexE', 'aadA2b', 'erm(35)', 'acc3-iva', 'aadD', 'penA', 'aac(3)-iid_iii_iif_iia_iie', 'bexA/norM', 'blaCTX-M', 'catB9', 'cmlA5', 'acrR', 'sul2', "aph(3'')-ia", 'vanYD', 'tet44', 'norA', 'aph6ia', 'blaOXA10', 'tetC', 'vanHD', 'dfra21', 'dfra14', 'VanB', 'blaFOXnew', 'cadC', 'qnrS2', 'dfrBmulti', 'mdtE/yhiU', 'dfra17', 'adeI', 'pikR2', 'blaCARB', 'cat', 'aadA2a', 'blaMOX/blaCMY', 'bl3_cpha', 'dfrA15', 'pbrT', 'cefa_ampc', 'ttgB', 'tetA', 'blaVIM', 'vanYB']
# ['ermY', 'bl1acc', 'vanRD', 'aac(6)-iw', 'lnuB', 'tet39', 'sulA/folP', 'catA1', 'cefa_qacelta', 'QnrS1_S3_S5', 'erm(B)', 'vanRB', 'blaOCH', 'erm(Q)', 'lnu(F)', 'catA3', 'QnrB4', 'vanC2/vanC3', 'merA-marko', 'vanTG', 'bla-SME', 'tetX', 'blaHERA', 'aadA_99', 'blaIMI', 'msr(A)', 'vanXA', 'qacF/Ha', 'vga(A)LC', 'aadA5', 'aadE', 'tetH', 'vat(E)', 'erm(F)b', 'cfxA', 'blaGES', 'aac(6)-is_iu_ix', 'erm(F)a', 'tcrB', 'vanWB', 'mefA', 'vanA', 'ant6-ib', 'ermA/ermTR', 'erm(A)']
# ['vgaB', 'tetS', 'aph_viii', 'qnrS2', 'terW', 'erm(D)', 'ampC/blaDHA', 'lsa(C)', 'aadD', 'sul2', 'ermX', 'mtrD', 'aadA2b', 'pikR2', 'tetPB', 'blaLEN', 'dfra21', 'apmA', 'dfrA10', 'blaCTX-M', 'catB9', 'catP']

# %%
corrs
# Out:
# {'plastic_ex_corrs': {'tnpAa': ['blaCTX-M',
#    'catB9',
#    'sul2',
#    'qepA_1_2',
#    'ant6-ia',
#    'tetR',
#    'tetQ',
#    'catB3',
#    'tet44',
#    'blaOXA10',
#    'qnrB-bob_resign',
#    "aac(6')-Ib",
#    'tetC',
#    'erm(S)',
#    'blaGES',
#    'strA',
#    'cat',
#    'aadA2a',
#    'blaMOX/blaCMY',
#    'dfrA15',
#    'tetH',
#    'cefa_ampc',
#    'mefA',
#    'strB',
#    'aadB',
#    'mdth',
#    'vanC',
#    'aadA_99',
#    'vat(E)',
#    'bla-SME',
#    'mef(B)',
#    'mphA',
#    'acrF',
#    'sulA/folP',
#    'ttgB',
#    'pica',
#    'blaOCH',
#    'blaIMI',
#    'sugE',
#    'vgaB',
#    'cfiA',
#    'bla1',
#    'blaPSE',
#    'pbp',
#    'erm(35)',
#    'aadD',
#    'dfrA25',
#    'bexA/norM'],
#   'IS3': ['cmlA5',
#    'tetA',
#    'blaVIM',
#    "aph(3'')-ia",
#    'strB',
#    'norA',
#    'vanSB',
#    'mdth',
#    'cmlA1',
#    'aac(3)-Xab',
#    'lsa(C)',
#    'vanC',
#    'QnrVC1_VC3_VC6',
#    'dfrA10',
#    'aac(6)-ij',
#    'aph_viii',
#    'merA-marko',
#    'terW',
#    'dfrBmulti',
#    'aac(3)-xaa',
#    'bla-L1',
#    'aadA17',
#    'vatB',
#    'arsA',
#    'blaPAO/PDC',
#    'mexA',
#    'tetPB',
#    'carB',
#    'mef(B)',
#    'acrB',
#    'blaCMY',
#    'blaSHV-11',
#    'dfrK',
#    'cmx(A)',
#    'ttgB',
#    'tetS',
#    'NDM new',
#    'msr(C)',
#    'ermX',
#    'blaOCH',
#    'ArmA',
#    'erm(42)',
#    'aphA1',
#    'ttgA',
#    'sul1 NEW',
#    'Aac6-Aph2',
#    'sugE',
#    'aadA10',
#    'ampC',
#    'vgaB',
#    'blaIMIR',
#    'dfrA27',
#    'catP',
#    'aac(6)-iv_ih',
#    'mtrD',
#    'mexE',
#    'aadA2b',
#    'erm(35)',
#    'blaLEN',
#    'acc3-iva',
#    'mepA',
#    'aadD',
#    'aac(3)-iid_iii_iif_iia_iie',
#    'bexA/norM',
#    'blaCTX-M',
#    'catB9',
#    'acrR',
#    'sul2',
#    'vanYD',
#    'tet44',
#    'aph6ia',
#    'blaOXA10',
#    'tetC',
#    'vanHD',
#    'dfra21',
#    'dfra14',
#    'VanB',
#    'blaFOXnew',
#    'cadC',
#    'qnrS2',
#    'mdtE/yhiU',
#    'dfra17',
#    'adeI',
#    'pikR2',
#    'lnu(F)',
#    'blaCARB',
#    'cat',
#    'aadA2a',
#    'blaMOX/blaCMY',
#    'bl3_cpha',
#    'dfrA15',
#    'vanRC',
#    'pbrT',
#    'cefa_ampc'],
#   'IS256': ['dfrA15',
#    'dfrK',
#    'cefa_ampc',
#    'tetB',
#    'ttgB',
#    'tetA',
#    'vanYB',
#    'ArmA',
#    'vanSB',
#    'erm(42)',
#    'mdth',
#    'cmlA1',
#    'spec_aph',
#    'lsa(C)',
#    'vanC',
#    'QnrVC1_VC3_VC6',
#    'sugE',
#    'aadA10',
#    'dfrA10',
#    'aac(6)-ij',
#    'vgaB',
#    'aph_viii',
#    'terW',
#    'tolC',
#    'aadA_99',
#    'msr(A)',
#    'erm(A)',
#    'bla-L1',
#    'aadA17',
#    'aac(6)-iv_ih',
#    "aac(6')-II",
#    'vatB',
#    'blaPAO/PDC',
#    'mexA',
#    'erm(35)',
#    'blaLEN',
#    'blaCMY',
#    'erm(D)',
#    'blaSHV-11',
#    'cmx(A)',
#    'dfrA25',
#    'pica',
#    'acrR',
#    'tetS',
#    'NDM new',
#    'msr(C)',
#    'ermX',
#    'blaOCH',
#    'apmA',
#    'vanC2/vanC3',
#    'ttgA',
#    "aac(6')-Ib",
#    'tetC',
#    'erm(S)',
#    'cmlV',
#    'ampC',
#    'ampC/blaDHA',
#    'blaFOXnew',
#    'blaGES',
#    'blaIMIR',
#    'dfrA27',
#    'cfiA',
#    'qnrS2',
#    'catP',
#    'blaPSE',
#    'mtrD',
#    'mexE',
#    'aadA2b',
#    'tetJ',
#    'aadD',
#    'vgaA',
#    'aac(3)-iid_iii_iif_iia_iie',
#    'bexA/norM',
#    'blaCTX-M',
#    'pbrT',
#    'catB9',
#    'cmlA5',
#    'tetE',
#    'blaVIM',
#    'sul2',
#    "aph(3'')-ia",
#    'catB3',
#    'vanYD',
#    'tet44',
#    'strB',
#    'norA',
#    'aph6ia',
#    'blaOXA10',
#    'qnrB-bob_resign',
#    'vanHD',
#    'dfra21',
#    'aac(3)-Xab',
#    'dfra14',
#    'VanB',
#    'cadC',
#    'dfrBmulti',
#    'erm(B)',
#    'dfra17',
#    'adeI',
#    'vanRB',
#    'aadA5',
#    'pikR2',
#    'blaCARB',
#    'strA',
#    'aac(3)-xaa',
#    'vat(E)',
#    'cat',
#    'aadA2a',
#    'arsA',
#    'blaMOX/blaCMY',
#    'ere(A)',
#    'tetPB',
#    'carB',
#    'bl3_cpha',
#    'mef(B)'],
#   'IncW_trwAB': ['aac(6)-iv_ih',
#    'mtrD',
#    "aac(6')-II",
#    'mexE',
#    'aadA2b',
#    'aac(6)-im',
#    'erm(35)',
#    'blaLEN',
#    'acc3-iva',
#    'aadD',
#    'penA',
#    'erm(D)',
#    'aac(3)-iid_iii_iif_iia_iie',
#    'bexA/norM',
#    'blaCTX-M',
#    'catB9',
#    'acrR',
#    'sul2',
#    'NDM new',
#    'vanYD',
#    'tet44',
#    'tetC',
#    'vanHD',
#    'VanB',
#    'blaFOXnew',
#    'cadC',
#    'qnrS2',
#    'catP',
#    'pikR2',
#    'blaCARB',
#    'cat',
#    'aadA2a',
#    'blaMOX/blaCMY',
#    'dfrA15',
#    'pbrT',
#    'cmlA5',
#    'tetA',
#    'blaVIM',
#    'vanWB',
#    "aph(3'')-ia",
#    'norA',
#    'aph6ia',
#    'blaOXA10',
#    'mdth',
#    'dfra21',
#    'cmlA1',
#    'aac(3)-Xab',
#    'dfra14',
#    'lsa(C)',
#    'QnrVC1_VC3_VC6',
#    'dfrA10',
#    'aac(6)-ij',
#    'aph_viii',
#    'merA-marko',
#    'terW',
#    'dfrBmulti',
#    'dfra17',
#    'adeI',
#    'aac(3)-xaa',
#    'bla-L1',
#    'aadA17',
#    'vatB',
#    'arsA',
#    'blaPAO/PDC',
#    'mexA',
#    'tetPB',
#    'carB',
#    'bl3_cpha',
#    'mef(B)',
#    'blaCMY',
#    'blaSHV-11',
#    'dfrK',
#    'cmx(A)',
#    'cefa_ampc',
#    'ttgB',
#    'tetS',
#    'vanYB',
#    'msr(C)',
#    'ermX',
#    'ArmA',
#    'vanSB',
#    'erm(42)',
#    'apmA',
#    'ttgA',
#    'sugE',
#    'aadA10',
#    'ampC',
#    'ampC/blaDHA',
#    'vgaB',
#    'blaIMIR',
#    'dfrA27'],
#   'mcr-1': ['cefa_ampc',
#    'tetB',
#    'ttgB',
#    'tetA',
#    'pica',
#    'tetS',
#    'vanYB',
#    'msr(C)',
#    'ermX',
#    'ArmA',
#    'vanSB',
#    'erm(42)',
#    'apmA',
#    'mdth',
#    'ttgA',
#    'spec_aph',
#    'Aac6-Aph2',
#    'sugE',
#    'cmlV',
#    'aadA10',
#    'ampC/blaDHA',
#    'vgaB',
#    'terW',
#    'blaIMIR',
#    'dfrA27',
#    'cfiA',
#    'msr(A)',
#    'erm(A)',
#    'aac(6)-iv_ih',
#    'mtrD',
#    "aac(6')-II",
#    'aadA2b',
#    'blaPAO/PDC',
#    'erm(35)',
#    'blaLEN',
#    'mepA',
#    'aadD',
#    'erm(D)',
#    'blaSHV-11',
#    'aac(3)-iid_iii_iif_iia_iie',
#    'cmx(A)',
#    'dfrA25',
#    'bexA/norM',
#    'blaCTX-M',
#    'catB9',
#    'tetE',
#    'acrR',
#    'NDM new',
#    'vanYD',
#    'blaOCH',
#    'vanC2/vanC3',
#    'qnrB-bob_resign',
#    "aac(6')-Ib",
#    'tetC',
#    'vanHD',
#    'erm(S)',
#    'VanB',
#    'ampC',
#    'blaFOXnew',
#    'blaGES',
#    'cadC',
#    'qnrS2',
#    'catP',
#    'erm(B)',
#    'vanRB',
#    'blaPSE',
#    'pikR2',
#    'blaCARB',
#    'mexE',
#    'cat',
#    'blaMOX/blaCMY',
#    'tetJ',
#    'vgaA',
#    'dfrA15',
#    'pbrT',
#    'cmlA5',
#    'blaVIM',
#    'sul2',
#    "aph(3'')-ia",
#    'catB3',
#    'tet44',
#    'strB',
#    'norA',
#    'aph6ia',
#    'blaOXA10',
#    'dfra21',
#    'cmlA1',
#    'aac(3)-Xab',
#    'dfra14',
#    'lsa(C)',
#    'vanC',
#    'QnrVC1_VC3_VC6',
#    'dfrA10',
#    'aac(6)-ij',
#    'aph_viii',
#    'tolC',
#    'aadA_99',
#    'dfrBmulti',
#    'dfra17',
#    'adeI',
#    'aadA5',
#    'strA',
#    'aac(3)-xaa',
#    'bla-L1',
#    'vat(E)',
#    'aadA17',
#    'aadA2a',
#    'vatB',
#    'arsA',
#    'ere(A)',
#    'mexA',
#    'tetPB',
#    'carB',
#    'bl3_cpha',
#    'mef(B)',
#    'blaCMY',
#    'dfrK'],
#   'tnpAf': ['tetS',
#    'vanYB',
#    'msr(C)',
#    'vanSB',
#    'erm(42)',
#    'mdth',
#    'cmlA1',
#    'spec_aph',
#    'lsa(C)',
#    'QnrVC1_VC3_VC6',
#    'sugE',
#    'cmlV',
#    'aadA10',
#    'dfrA10',
#    'ampC/blaDHA',
#    'vgaB',
#    'blaIMIR',
#    'aadA_99',
#    'msr(A)',
#    'erm(A)',
#    'bla1',
#    'vanHB',
#    'bla-L1',
#    'aac(6)-iv_ih',
#    "aac(6')-II",
#    'vatB',
#    'blaPAO/PDC',
#    'pbp',
#    'mexA',
#    'erm(35)',
#    'aadD',
#    'erm(D)',
#    'blaSHV-11',
#    'cmx(A)',
#    'dfrA25',
#    'blaCTX-M',
#    'sulA/folP',
#    'pica',
#    'acrR',
#    'NDM new',
#    'tetR',
#    'tetQ',
#    'ermX',
#    'vanYD',
#    'blaOCH',
#    'apmA',
#    'vanC2/vanC3',
#    'ttgA',
#    "aac(6')-Ib",
#    'tetC',
#    'erm(S)',
#    'VanB',
#    'ampC',
#    'dfrA27',
#    'cfiA',
#    'qnrS2',
#    'catP',
#    'vanRB',
#    'blaPSE',
#    'pikR2',
#    'cat',
#    'aadA2b',
#    'tetJ',
#    'vgaA',
#    'dfrA15',
#    'aac(3)-iid_iii_iif_iia_iie',
#    'bexA/norM',
#    'pbrT',
#    'catB9',
#    'cmlA5',
#    'tetE',
#    'blaVIM',
#    'sul2',
#    'tet44',
#    'strB',
#    'norA',
#    'aph6ia',
#    'aadA6',
#    'blaOXA10',
#    'vanHD',
#    'dfra21',
#    'aac(3)-Xab',
#    'vanC',
#    'aac(6)-ij',
#    'cadC',
#    'aph_viii',
#    'tolC',
#    'dfrBmulti',
#    'erm(B)',
#    'dfra17',
#    'adeI',
#    'aadA5',
#    'blaCARB',
#    'strA',
#    'aac(3)-xaa',
#    'aadA2a',
#    'arsA',
#    'blaMOX/blaCMY',
#    'ere(A)',
#    'tetPB',
#    'carB',
#    'mef(B)',
#    'blaCMY',
#    'dfrK',
#    'cefa_ampc',
#    'tetB',
#    'tetL',
#    'ttgB',
#    'tetA'],
#   'IS613': ['carB',
#    'bl3_cpha',
#    'mef(B)',
#    'acrB',
#    'blaCMY',
#    'blaSHV-11',
#    'dfrK',
#    'cmx(A)',
#    'cefa_ampc',
#    'ttgB',
#    'tetS',
#    'msr(C)',
#    'ermX',
#    'blaOCH',
#    'ArmA',
#    'erm(42)',
#    'ttgA',
#    'sul1 NEW',
#    'Aac6-Aph2',
#    'sugE',
#    'aadA10',
#    'cfxA',
#    'ampC',
#    'ampC/blaDHA',
#    'vgaB',
#    'blaIMIR',
#    'dfrA27',
#    'cfiA',
#    'aac(6)-iv_ih',
#    'mtrD',
#    'mexE',
#    'aadA2b',
#    'erm(35)',
#    'blaLEN',
#    'acc3-iva',
#    'mepA',
#    'aadD',
#    'aac(3)-iid_iii_iif_iia_iie',
#    'dfrA25',
#    'bexA/norM',
#    'blaCTX-M',
#    'catB9',
#    'acrR',
#    'sul2',
#    'NDM new',
#    'vanYD',
#    'tet44',
#    'aphA1',
#    'tetC',
#    'vanHD',
#    'erm(S)',
#    'VanB',
#    'blaFOXnew',
#    'cadC',
#    'qnrS2',
#    'catP',
#    'mdtE/yhiU',
#    'pikR2',
#    'blaCARB',
#    'cat',
#    'aadA2a',
#    'blaMOX/blaCMY',
#    'aadA9',
#    'dfrA15',
#    'vanRC',
#    'pbrT',
#    'cmlA5',
#    'tetA',
#    'blaVIM',
#    "aph(3'')-ia",
#    'strB',
#    'norA',
#    'aph6ia',
#    'vanSB',
#    'blaOXA10',
#    'mdth',
#    'dfra21',
#    'cmlA1',
#    'aac(3)-Xab',
#    'lsa(C)',
#    'vanC',
#    'QnrVC1_VC3_VC6',
#    'dfrA10',
#    'aph_viii',
#    'merA-marko',
#    'terW',
#    'dfrBmulti',
#    'dfra17',
#    'adeI',
#    'aac(3)-xaa',
#    'bla-L1',
#    'aadA17',
#    'vatB',
#    'arsA',
#    'blaPAO/PDC',
#    'mexA',
#    'tetPB'],
#   'int1-a-marko': ['catP',
#    'vanRB',
#    'blaPSE',
#    'pikR2',
#    'mtrD',
#    'mexE',
#    'cat',
#    'beta_ccra',
#    'aadA2b',
#    'blaMOX/blaCMY',
#    'tetJ',
#    'vgaA',
#    'dfrA15',
#    'aac(3)-iid_iii_iif_iia_iie',
#    'vanRC',
#    'pbrT',
#    'catB9',
#    'cmlA5',
#    'tetE',
#    'blaVIM',
#    'sul2',
#    'erm(F)a',
#    "aph(3'')-ia",
#    'catB3',
#    'tet44',
#    'strB',
#    'norA',
#    'aph6ia',
#    'aadA6',
#    'blaOXA10',
#    'vanHD',
#    'dfra21',
#    'aac(3)-Xab',
#    'vanC',
#    'aac(6)-ij',
#    'cadC',
#    'aph_viii',
#    'tolC',
#    'dfrBmulti',
#    'erm(B)',
#    'dfra17',
#    'adeI',
#    'aadA5',
#    'blaCARB',
#    'strA',
#    'aac(3)-xaa',
#    'aadA2a',
#    'arsA',
#    'ere(A)',
#    'mexA',
#    'tetPB',
#    'carB',
#    'mef(B)',
#    'blaCMY',
#    'dfrK',
#    'cefa_ampc',
#    'tetB',
#    'tetL',
#    'ttgB',
#    'tetA',
#    'mefA',
#    'tetS',
#    'vanYB',
#    'msr(C)',
#    'ArmA',
#    'vanSB',
#    'erm(42)',
#    'mdth',
#    'qnrS2',
#    'cmlA1',
#    'spec_aph',
#    'lsa(C)',
#    'QnrVC1_VC3_VC6',
#    'sugE',
#    'cmlV',
#    'aadA10',
#    'dfrA10',
#    'ampC/blaDHA',
#    'vgaB',
#    'blaIMIR',
#    'dfrA27',
#    'msr(A)',
#    'erm(A)',
#    'bla1',
#    'vanHB',
#    'bla-L1',
#    'aac(6)-iv_ih',
#    "aac(6')-II",
#    'vatB',
#    'blaPAO/PDC',
#    'erm(35)',
#    'mepA',
#    'aadD',
#    'erm(D)',
#    'blaSHV-11',
#    'cmx(A)',
#    'dfrA25',
#    'bexA/norM',
#    'blaCTX-M',
#    'pica',
#    'acrR',
#    'NDM new',
#    'tetR',
#    'ermX',
#    'vanYD',
#    'blaOCH',
#    'apmA',
#    'vanC2/vanC3',
#    'ttgA',
#    'qnrB-bob_resign',
#    "aac(6')-Ib",
#    'tetC',
#    'erm(S)',
#    'VanB',
#    'ampC',
#    'blaFOXnew',
#    'cfiA'],
#   'tra-A': ['ArmA',
#    'erm(42)',
#    'apmA',
#    'ttgA',
#    'spec_aph',
#    'sugE',
#    'cmlV',
#    'aadA10',
#    'ampC',
#    'ampC/blaDHA',
#    'vgaB',
#    'blaIMIR',
#    'dfrA27',
#    'cfiA',
#    'msr(A)',
#    'erm(A)',
#    'aac(6)-iv_ih',
#    'mtrD',
#    "aac(6')-II",
#    'mexE',
#    'aadA2b',
#    'aac(6)-im',
#    'erm(35)',
#    'blaLEN',
#    'penA',
#    'erm(D)',
#    'aac(3)-iid_iii_iif_iia_iie',
#    'dfrA25',
#    'bexA/norM',
#    'blaCTX-M',
#    'catB9',
#    'tetE',
#    'sul2',
#    'NDM new',
#    'vanYD',
#    'tet44',
#    'tetC',
#    'vanHD',
#    'cadC',
#    'qnrS2',
#    'catP',
#    'erm(B)',
#    'vanRB',
#    'pikR2',
#    'blaCARB',
#    'aac(6)-ir',
#    'cat',
#    'aadA2a',
#    'blaMOX/blaCMY',
#    'dfrA15',
#    'pbrT',
#    'cmlA5',
#    'tetA',
#    'blaVIM',
#    'vanWB',
#    "aph(3'')-ia",
#    'norA',
#    'aph6ia',
#    'vanSB',
#    'blaOXA10',
#    'dfra21',
#    'aac(3)-Xab',
#    'lsa(C)',
#    'QnrVC1_VC3_VC6',
#    'dfrA10',
#    'aph_viii',
#    'terW',
#    'dfrBmulti',
#    'dfra17',
#    'adeI',
#    'bla-L1',
#    'vatB',
#    'arsA',
#    'ere(A)',
#    'blaPAO/PDC',
#    'mexA',
#    'tetPB',
#    'carB',
#    'bl3_cpha',
#    'mef(B)',
#    'blaCMY',
#    'blaSHV-11',
#    'dfrK',
#    'aac(6)-iz',
#    'cefa_ampc',
#    'cmx(A)',
#    'tetB',
#    'ttgB',
#    'tetS',
#    'vanYB',
#    'msr(C)',
#    'ermX'],
#   'IncI1_repI1': ['spec_aph',
#    'lsa(C)',
#    'vanC',
#    'QnrVC1_VC3_VC6',
#    'sugE',
#    'aadA10',
#    'aac(6)-ij',
#    'vgaB',
#    'aph_viii',
#    'terW',
#    'tolC',
#    'aadA_99',
#    'msr(A)',
#    'aadA5',
#    'bla-L1',
#    "aac(6')-II",
#    'vatB',
#    'blaPAO/PDC',
#    'mexA',
#    'erm(35)',
#    'tetPB',
#    'blaLEN',
#    'mef(B)',
#    'blaCMY',
#    'erm(D)',
#    'blaSHV-11',
#    'dfrK',
#    'cmx(A)',
#    'dfrA25',
#    'tetS',
#    'QnrS1_S3_S5',
#    'NDM new',
#    'ant6-ia',
#    'msr(C)',
#    'tetQ',
#    'ermX',
#    'blaOCH',
#    'apmA',
#    'vanC2/vanC3',
#    'ttgA',
#    'blaIMI',
#    'cmlV',
#    'ampC',
#    'ampC/blaDHA',
#    'blaGES',
#    'blaIMIR',
#    'dfrA27',
#    'cfiA',
#    'erm(A)',
#    'catP',
#    'mtrD',
#    'mexE',
#    'aadA2b',
#    'tetJ',
#    'aadD',
#    'aac(3)-iid_iii_iif_iia_iie',
#    'bexA/norM',
#    'blaCTX-M',
#    'catB9',
#    'cmlA5',
#    'tetE',
#    'acrR',
#    'sul2',
#    "aph(3'')-ia",
#    'vanYD',
#    'tet44',
#    'norA',
#    'aph6ia',
#    'aadA6',
#    'blaOXA10',
#    'tetC',
#    'vanHD',
#    'dfra21',
#    'aac(3)-Xab',
#    'cadC',
#    'qnrS2',
#    'erm(B)',
#    'dfra17',
#    'adeI',
#    'vanRB',
#    'pikR2',
#    'blaCARB',
#    'aac(3)-xaa',
#    'vat(E)',
#    'cat',
#    'aadA2a',
#    'arsA',
#    'bla-SME',
#    'blaMOX/blaCMY',
#    'ere(A)',
#    'carB',
#    'bl3_cpha',
#    'vgaA',
#    'dfrA15',
#    'pbrT',
#    'cefa_ampc',
#    'tetB',
#    'ttgB',
#    'tetA',
#    'blaVIM',
#    'vanYB',
#    'strB',
#    'aadB',
#    'ArmA',
#    'vanSB',
#    'erm(42)',
#    'mdth',
#    'cmlA1'],
#   'cro': ['vanC',
#    'tolC',
#    'aadA_99',
#    'strA',
#    'vat(E)',
#    'bla-SME',
#    'mef(B)',
#    'cefa_ampc',
#    'sulA/folP',
#    'ttgB',
#    'pica',
#    'mefA',
#    'blaOCH',
#    'sugE',
#    'ampC/blaDHA',
#    'vgaB',
#    'cfiA',
#    'bla1',
#    'blaPSE',
#    'pbp',
#    'erm(35)',
#    'dfrA25',
#    'acrF',
#    'bexA/norM',
#    'catB9',
#    'sul2',
#    'ant6-ia',
#    'tetR',
#    'tetQ',
#    'catB3',
#    'tet44',
#    'qnrB-bob_resign',
#    "aac(6')-Ib",
#    'tetC',
#    'blaIMI',
#    'erm(S)',
#    'blaGES',
#    'erm(B)',
#    'cat',
#    'aadA2a',
#    'dfrA15',
#    'tetH',
#    'aadB',
#    'blaOXA10',
#    'mdth'],
#   'Tn3': ['tetS',
#    'vanYB',
#    'msr(C)',
#    'aadB',
#    'erm(42)',
#    'mdth',
#    'cmlA1',
#    'spec_aph',
#    'sugE',
#    'cmlV',
#    'ampC/blaDHA',
#    'vgaB',
#    'blaIMIR',
#    'aadA_99',
#    'msr(A)',
#    'erm(A)',
#    'bla1',
#    'vanHB',
#    'aac(6)-iw',
#    "aac(6')-II",
#    'pbp',
#    'erm(35)',
#    'aadD',
#    'erm(D)',
#    'dfrA25',
#    'bexA/norM',
#    'blaCTX-M',
#    'sulA/folP',
#    'NDM new',
#    'ant6-ia',
#    'tetQ',
#    'ermX',
#    'blaOCH',
#    'apmA',
#    'vanC2/vanC3',
#    'tetC',
#    'blaIMI',
#    'erm(S)',
#    'ampC',
#    'cfiA',
#    'vanRB',
#    'catA3',
#    'cat',
#    'blaMOX/blaCMY',
#    'tetJ',
#    'vgaA',
#    'dfrA15',
#    'tetH',
#    'catB9',
#    'tetE',
#    'vanTG',
#    'sul2',
#    "aph(3'')-ia",
#    'aac(3)-id_ie',
#    'tet44',
#    'strB',
#    'aadA6',
#    'blaOXA10',
#    'vanC',
#    'aac(6)-ij',
#    'tolC',
#    'erm(B)',
#    'adeI',
#    'aadA5',
#    'blaCARB',
#    'aac(3)-xaa',
#    'aadA2a',
#    'bla-SME',
#    'ere(A)',
#    'tetPB',
#    'carB',
#    'mef(B)',
#    'cefa_ampc',
#    'tetB',
#    'tetL',
#    'ttgB'],
#   'dfrA12': ['msr(C)',
#    'ermX',
#    'blaOCH',
#    'ArmA',
#    'erm(42)',
#    'ttgA',
#    'sul1 NEW',
#    'Aac6-Aph2',
#    'sugE',
#    'cmlV',
#    'aadA10',
#    'cfxA',
#    'ampC',
#    'ampC/blaDHA',
#    'vgaB',
#    'blaIMIR',
#    'dfrA27',
#    'cfiA',
#    'aac(6)-iv_ih',
#    'mtrD',
#    'mexE',
#    'aadA2b',
#    'erm(35)',
#    'blaLEN',
#    'acc3-iva',
#    'mepA',
#    'aadD',
#    'aac(3)-iid_iii_iif_iia_iie',
#    'dfrA25',
#    'bexA/norM',
#    'blaCTX-M',
#    'catB9',
#    'acrR',
#    'sul2',
#    'NDM new',
#    'vanYD',
#    'tet44',
#    'vanC2/vanC3',
#    'aphA1',
#    'tetC',
#    'vanHD',
#    'erm(S)',
#    'VanB',
#    'blaFOXnew',
#    'cadC',
#    'qnrS2',
#    'catP',
#    'erm(B)',
#    'pikR2',
#    'blaCARB',
#    'cat',
#    'aadA2a',
#    'blaMOX/blaCMY',
#    'dfrA15',
#    'vanRC',
#    'pbrT',
#    'cmlA5',
#    'tetA',
#    'blaVIM',
#    "aph(3'')-ia",
#    'strB',
#    'norA',
#    'aph6ia',
#    'vanSB',
#    'blaOXA10',
#    'mdth',
#    'dfra21',
#    'cmlA1',
#    'aac(3)-Xab',
#    'lsa(C)',
#    'vanC',
#    'QnrVC1_VC3_VC6',
#    'dfrA10',
#    'aac(6)-ij',
#    'aph_viii',
#    'merA-marko',
#    'terW',
#    'tolC',
#    'dfrBmulti',
#    'dfra17',
#    'adeI',
#    'aac(3)-xaa',
#    'bla-L1',
#    'aadA17',
#    'vatB',
#    'arsA',
#    'blaPAO/PDC',
#    'mexA',
#    'tetPB',
#    'carB',
#    'bl3_cpha',
#    'mef(B)',
#    'acrB',
#    'blaCMY',
#    'blaSHV-11',
#    'dfrK',
#    'cmx(A)',
#    'cefa_ampc',
#    'ttgB',
#    'tetS'],
#   'Tp614': ['tetC',
#    'vanHD',
#    'erm(S)',
#    'VanB',
#    'ampC',
#    'blaFOXnew',
#    'cadC',
#    'qnrS2',
#    'catP',
#    'mdtE/yhiU',
#    'pikR2',
#    'blaCARB',
#    'mexE',
#    'cat',
#    'blaMOX/blaCMY',
#    'aadA9',
#    'dfrA15',
#    'vanRC',
#    'pbrT',
#    'cmlA5',
#    'blaVIM',
#    'sul2',
#    "aph(3'')-ia",
#    'tet44',
#    'strB',
#    'norA',
#    'aph6ia',
#    'blaOXA10',
#    'dfra21',
#    'aac(3)-Xab',
#    'vanC',
#    'QnrVC1_VC3_VC6',
#    'dfrA10',
#    'aac(6)-ij',
#    'aph_viii',
#    'merA-marko',
#    'dfrBmulti',
#    'dfra17',
#    'adeI',
#    'aac(3)-xaa',
#    'aadA17',
#    'aadA2a',
#    'vatB',
#    'arsA',
#    'mexA',
#    'tetPB',
#    'carB',
#    'bl3_cpha',
#    'mef(B)',
#    'acrB',
#    'blaCMY',
#    'dfrK',
#    'cefa_ampc',
#    'ttgB',
#    'tetA',
#    'tetS',
#    'msr(C)',
#    'ermX',
#    'ArmA',
#    'vanSB',
#    'erm(42)',
#    'mdth',
#    'ttgA',
#    'sul1 NEW',
#    'cmlA1',
#    'lsa(C)',
#    'sugE',
#    'aadA10',
#    'cfxA',
#    'vgaB',
#    'terW',
#    'blaIMIR',
#    'dfrA27',
#    'cfiA',
#    'bla-L1',
#    'aac(6)-iv_ih',
#    'mtrD',
#    'aadA2b',
#    'blaPAO/PDC',
#    'erm(35)',
#    'blaLEN',
#    'acc3-iva',
#    'mepA',
#    'aadD',
#    'blaSHV-11',
#    'aac(3)-iid_iii_iif_iia_iie',
#    'cmx(A)',
#    'dfrA25',
#    'bexA/norM',
#    'blaCTX-M',
#    'catB9',
#    'acrR',
#    'NDM new',
#    'vanYD',
#    'blaOCH',
#    'aphA1'],
#   'ARR-3': ['ermX',
#    'ArmA',
#    'vanSB',
#    'erm(42)',
#    'apmA',
#    'mdth',
#    'ttgA',
#    'spec_aph',
#    'sugE',
#    'cmlV',
#    'aadA10',
#    'ampC/blaDHA',
#    'vgaB',
#    'blaIMIR',
#    'dfrA27',
#    'cfiA',
#    'msr(A)',
#    'erm(A)',
#    'aac(6)-iv_ih',
#    'mtrD',
#    "aac(6')-II",
#    'aadA2b',
#    'aac(6)-im',
#    'erm(35)',
#    'blaLEN',
#    'penA',
#    'erm(D)',
#    'blaSHV-11',
#    'aac(3)-iid_iii_iif_iia_iie',
#    'dfrA25',
#    'bexA/norM',
#    'blaCTX-M',
#    'catB9',
#    'tetE',
#    'sul2',
#    'NDM new',
#    'vanYD',
#    'blaOCH',
#    'vanC2/vanC3',
#    'tetC',
#    'vanHD',
#    'erm(S)',
#    'VanB',
#    'ampC',
#    'blaFOXnew',
#    'cadC',
#    'qnrS2',
#    'catP',
#    'erm(B)',
#    'vanRB',
#    'pikR2',
#    'blaCARB',
#    'mexE',
#    'cat',
#    'aadA2a',
#    'blaMOX/blaCMY',
#    'tetJ',
#    'dfrA15',
#    'pbrT',
#    'cmlA5',
#    'tetA',
#    'blaVIM',
#    'vanWB',
#    "aph(3'')-ia",
#    'tet44',
#    'norA',
#    'aph6ia',
#    'blaOXA10',
#    'dfra21',
#    'aac(3)-Xab',
#    'lsa(C)',
#    'vanC',
#    'QnrVC1_VC3_VC6',
#    'dfrA10',
#    'aph_viii',
#    'terW',
#    'dfrBmulti',
#    'dfra17',
#    'adeI',
#    'aadA5',
#    'aac(3)-xaa',
#    'bla-L1',
#    'vatB',
#    'arsA',
#    'ere(A)',
#    'blaPAO/PDC',
#    'mexA',
#    'bl3_cpha',
#    'mef(B)',
#    'blaCMY',
#    'dfrK',
#    'cmx(A)',
#    'cefa_ampc',
#    'tetB',
#    'ttgB',
#    'vanYB',
#    'msr(C)'],
#   'TN5': ['vatB',
#    'pbp',
#    'erm(35)',
#    'aadD',
#    'erm(D)',
#    'dfrA25',
#    'blaCTX-M',
#    'sulA/folP',
#    'acrR',
#    'NDM new',
#    'tetQ',
#    'ermX',
#    'blaOCH',
#    'apmA',
#    'vanC2/vanC3',
#    'tetC',
#    'blaIMI',
#    'erm(S)',
#    'ampC',
#    'dfrA27',
#    'cfiA',
#    'catP',
#    'vanRB',
#    'cat',
#    'aadA2b',
#    'tetJ',
#    'vgaA',
#    'dfrA15',
#    'tetH',
#    'bexA/norM',
#    'catB9',
#    'tetE',
#    'blaVIM',
#    'sul2',
#    "aph(3'')-ia",
#    'tet44',
#    'strB',
#    'aadA6',
#    'blaOXA10',
#    'vanC',
#    'aac(6)-ij',
#    'tolC',
#    'erm(B)',
#    'adeI',
#    'aadA5',
#    'blaCARB',
#    'aac(3)-xaa',
#    'aadA2a',
#    'blaMOX/blaCMY',
#    'ere(A)',
#    'tetPB',
#    'carB',
#    'bl3_cpha',
#    'mef(B)',
#    'cefa_ampc',
#    'tetB',
#    'tetL',
#    'ttgB',
#    'tetA',
#    'mefA',
#    'tetS',
#    'vanYB',
#    'msr(C)',
#    'aadB',
#    'erm(42)',
#    'mdth',
#    'cmlA1',
#    'spec_aph',
#    'sugE',
#    'cmlV',
#    'ampC/blaDHA',
#    'vgaB',
#    'blaIMIR',
#    'msr(A)',
#    'erm(A)',
#    'bla1',
#    'vanHB',
#    'bla-L1',
#    "aac(6')-II"],
#   'IS200a': ['vanC2/vanC3',
#    'qnrB-bob_resign',
#    "aac(6')-Ib",
#    'tetC',
#    'vanHD',
#    'dfra21',
#    'erm(S)',
#    'VanB',
#    'blaFOXnew',
#    'blaGES',
#    'cadC',
#    'qnrS2',
#    'catP',
#    'erm(B)',
#    'dfra17',
#    'vanRB',
#    'pikR2',
#    'blaCARB',
#    'cat',
#    'aadA2a',
#    'blaMOX/blaCMY',
#    'bl3_cpha',
#    'vgaA',
#    'dfrA15',
#    'tetH',
#    'pbrT',
#    'cefa_ampc',
#    'cmlA5',
#    'tetA',
#    'blaVIM',
#    "aph(3'')-ia",
#    'strB',
#    'aadB',
#    'norA',
#    'aph6ia',
#    'vanSB',
#    'blaOXA10',
#    'mdth',
#    'cmlA1',
#    'aac(3)-Xab',
#    'lsa(C)',
#    'vanC',
#    'QnrVC1_VC3_VC6',
#    'dfrA10',
#    'aac(6)-ij',
#    'aph_viii',
#    'terW',
#    'blaHERA',
#    'tolC',
#    'dfrBmulti',
#    'adeI',
#    'aadA5',
#    'aac(3)-xaa',
#    'bla-L1',
#    'vat(E)',
#    "aac(6')-II",
#    'vatB',
#    'arsA',
#    'ere(A)',
#    'blaPAO/PDC',
#    'mexA',
#    'tetPB',
#    'carB',
#    'mef(B)',
#    'blaCMY',
#    'blaSHV-11',
#    'dfrK',
#    'cmx(A)',
#    'tetB',
#    'tetL',
#    'sulA/folP',
#    'ttgB',
#    'pica',
#    'mefA',
#    'tetS',
#    'NDM new',
#    'vanYB',
#    'msr(C)',
#    'ermX',
#    'blaOCH',
#    'ArmA',
#    'erm(42)',
#    'apmA',
#    'ttgA',
#    'spec_aph',
#    'blaIMI',
#    'sugE',
#    'cmlV',
#    'aadA10',
#    'ampC',
#    'ampC/blaDHA',
#    'vgaB',
#    'blaIMIR',
#    'dfrA27',
#    'cfiA',
#    'msr(A)',
#    'erm(A)',
#    'blaPSE',
#    'aac(6)-iv_ih',
#    'mtrD',
#    'cepA',
#    'mexE',
#    'aadA2b',
#    'pbp',
#    'erm(35)',
#    'blaLEN',
#    'mepA',
#    'tetJ',
#    'aadD',
#    'erm(D)',
#    'aac(3)-iid_iii_iif_iia_iie',
#    'dfrA25',
#    'bexA/norM',
#    'blaCTX-M',
#    'catB9',
#    'tetE',
#    'acrR',
#    'sul2',
#    'tetR',
#    'catB3',
#    'vanYD',
#    'tet44',
#    'aadA6'],
#   'ISAba3-Acineto': ['strB',
#    'vanSB',
#    'mdth',
#    'cmlA1',
#    'aac(3)-Xab',
#    'lsa(C)',
#    'QnrVC1_VC3_VC6',
#    'sugE',
#    'aadA10',
#    'dfrA10',
#    'aac(6)-ij',
#    'vgaB',
#    'aph_viii',
#    'terW',
#    'aac(3)-xaa',
#    'bla-L1',
#    'aadA17',
#    'aac(6)-iv_ih',
#    "aac(6')-II",
#    'vatB',
#    'arsA',
#    'blaPAO/PDC',
#    'aac(6)-im',
#    'mexA',
#    'tetPB',
#    'blaLEN',
#    'carB',
#    'mef(B)',
#    'blaCMY',
#    'erm(D)',
#    'blaSHV-11',
#    'dfrK',
#    'cmx(A)',
#    'tetS',
#    'NDM new',
#    'msr(C)',
#    'ermX',
#    'ArmA',
#    'erm(42)',
#    'apmA',
#    'ttgA',
#    'ampC',
#    'ampC/blaDHA',
#    'blaIMIR',
#    'dfrA27',
#    'catP',
#    'mtrD',
#    'mexE',
#    'aadA2b',
#    'erm(35)',
#    'acc3-iva',
#    'aadD',
#    'penA',
#    'aac(3)-iid_iii_iif_iia_iie',
#    'bexA/norM',
#    'blaCTX-M',
#    'catB9',
#    'cmlA5',
#    'acrR',
#    'sul2',
#    "aph(3'')-ia",
#    'vanYD',
#    'tet44',
#    'norA',
#    'aph6ia',
#    'blaOXA10',
#    'tetC',
#    'vanHD',
#    'dfra21',
#    'dfra14',
#    'VanB',
#    'blaFOXnew',
#    'cadC',
#    'qnrS2',
#    'dfrBmulti',
#    'mdtE/yhiU',
#    'dfra17',
#    'adeI',
#    'pikR2',
#    'blaCARB',
#    'cat',
#    'aadA2a',
#    'blaMOX/blaCMY',
#    'bl3_cpha',
#    'dfrA15',
#    'pbrT',
#    'cefa_ampc',
#    'ttgB',
#    'tetA',
#    'blaVIM',
#    'vanYB'],
#   'nisB': ['blaOXA10',
#    'tetC',
#    'erm(S)',
#    'erm(B)',
#    'adeI',
#    'vanRB',
#    'blaCARB',
#    'catA3',
#    'cat',
#    'aadA2a',
#    'bla-SME',
#    'blaMOX/blaCMY',
#    'ere(A)',
#    'vgaA',
#    'dfrA15',
#    'tetH',
#    'cefa_ampc',
#    'tetB',
#    'ttgB',
#    'vanYB',
#    "aph(3'')-ia",
#    'aac(3)-id_ie',
#    'strB',
#    'aadB',
#    'mdth',
#    'cmlA1',
#    'spec_aph',
#    'vanC',
#    'sugE',
#    'aac(6)-ij',
#    'tolC',
#    'aadA_99',
#    'msr(A)',
#    'aadA5',
#    'aac(3)-xaa',
#    "aac(6')-II",
#    'tetPB',
#    'carB',
#    'mef(B)',
#    'dfrA25',
#    'tetL',
#    'sulA/folP',
#    'tetS',
#    'NDM new',
#    'ant6-ia',
#    'msr(C)',
#    'tetQ',
#    'ermX',
#    'blaOCH',
#    'erm(42)',
#    'apmA',
#    'blaIMI',
#    'cmlV',
#    'ampC',
#    'ampC/blaDHA',
#    'vgaB',
#    'blaIMIR',
#    'cfiA',
#    'erm(A)',
#    'bla1',
#    'vanHB',
#    'aac(6)-iw',
#    'pbp',
#    'erm(35)',
#    'tetJ',
#    'aadD',
#    'erm(D)',
#    'bexA/norM',
#    'blaCTX-M',
#    'catB9',
#    'tetE',
#    'vanTG',
#    'sul2',
#    'tet44',
#    'aadA6',
#    'vanC2/vanC3'],
#   'bacA': ['cadC',
#    'aph_viii',
#    'merA-marko',
#    'tolC',
#    'dfrBmulti',
#    'dfra17',
#    'adeI',
#    'pikR2',
#    'blaCARB',
#    'aac(3)-xaa',
#    'aadA17',
#    'aadA2a',
#    'arsA',
#    'blaMOX/blaCMY',
#    'bl3_cpha',
#    'mef(B)',
#    'blaCMY',
#    'dfrK',
#    'cefa_ampc',
#    'ttgB',
#    'tetA',
#    'tetS',
#    'msr(C)',
#    'ArmA',
#    'vanSB',
#    'erm(42)',
#    'mdth',
#    'sul1 NEW',
#    'cmlA1',
#    'lsa(C)',
#    'vanC',
#    'QnrVC1_VC3_VC6',
#    'sugE',
#    'aadA10',
#    'dfrA10',
#    'ampC/blaDHA',
#    'vgaB',
#    'terW',
#    'blaIMIR',
#    'bla-L1',
#    'aac(6)-iv_ih',
#    'vatB',
#    'blaPAO/PDC',
#    'mexA',
#    'erm(35)',
#    'blaLEN',
#    'acc3-iva',
#    'aadD',
#    'acrB',
#    'blaSHV-11',
#    'cmx(A)',
#    'dfrA25',
#    'blaCTX-M',
#    'acrR',
#    'NDM new',
#    'ermX',
#    'vanYD',
#    'blaOCH',
#    'aphA1',
#    'ttgA',
#    'tetC',
#    'erm(S)',
#    'cmlV',
#    'ampC',
#    'blaFOXnew',
#    'dfrA27',
#    'cfiA',
#    'qnrS2',
#    'catP',
#    'mtrD',
#    'mexE',
#    'cat',
#    'aadA2b',
#    'mepA',
#    'dfrA15',
#    'aac(3)-iid_iii_iif_iia_iie',
#    'vanRC',
#    'bexA/norM',
#    'pbrT',
#    'catB9',
#    'cmlA5',
#    'blaVIM',
#    'sul2',
#    "aph(3'')-ia",
#    'tet44',
#    'strB',
#    'norA',
#    'aph6ia',
#    'blaOXA10',
#    'vanHD',
#    'dfra21',
#    'aac(3)-Xab',
#    'VanB'],
#   'IncHI2-smr0018': ['aac(3)-Xab',
#    'dfra14',
#    'VanB',
#    'cadC',
#    'aph_viii',
#    'merA-marko',
#    'dfrBmulti',
#    'mdtE/yhiU',
#    'dfra17',
#    'adeI',
#    'pikR2',
#    'lnu(F)',
#    'blaCARB',
#    'aac(3)-xaa',
#    'aadA17',
#    'aadA2a',
#    'arsA',
#    'blaMOX/blaCMY',
#    'tetPB',
#    'carB',
#    'bl3_cpha',
#    'mef(B)',
#    'blaCMY',
#    'dfrK',
#    'cefa_ampc',
#    'ttgB',
#    'tetA',
#    'tetS',
#    'vanYB',
#    'msr(C)',
#    'ArmA',
#    'vanSB',
#    'erm(42)',
#    'mdth',
#    'sul1 NEW',
#    'cmlA1',
#    'lsa(C)',
#    'vanC',
#    'Aac6-Aph2',
#    'QnrVC1_VC3_VC6',
#    'sugE',
#    'aadA10',
#    'dfrA10',
#    'aac(6)-ij',
#    'vgaB',
#    'terW',
#    'blaIMIR',
#    'bla-L1',
#    'aac(6)-iv_ih',
#    'vatB',
#    'blaPAO/PDC',
#    'mexA',
#    'erm(35)',
#    'blaLEN',
#    'acc3-iva',
#    'aadD',
#    'penA',
#    'blaSHV-11',
#    'cmx(A)',
#    'blaCTX-M',
#    'acrR',
#    'NDM new',
#    'ermX',
#    'vanYD',
#    'ttgA',
#    'tetC',
#    'ampC',
#    'blaFOXnew',
#    'dfrA27',
#    'qnrS2',
#    'catP',
#    'mtrD',
#    'mexE',
#    'cat',
#    'aadA2b',
#    'dfrA15',
#    'aac(3)-iid_iii_iif_iia_iie',
#    'bexA/norM',
#    'pbrT',
#    'catB9',
#    'cmlA5',
#    'blaVIM',
#    'sul2',
#    "aph(3'')-ia",
#    'tet44',
#    'strB',
#    'norA',
#    'aph6ia',
#    'blaOXA10',
#    'vanHD',
#    'dfra21'],
#   'ISEcp1': ['pbp',
#    'erm(35)',
#    'blaLEN',
#    'aadD',
#    'erm(D)',
#    'aac(3)-iid_iii_iif_iia_iie',
#    'dfrA25',
#    'bexA/norM',
#    'blaCTX-M',
#    'catB9',
#    'tetE',
#    'acrR',
#    'sul2',
#    'NDM new',
#    'tetR',
#    'tetQ',
#    'tet44',
#    'aadA6',
#    'vanC2/vanC3',
#    'tetC',
#    'erm(S)',
#    'VanB',
#    'cadC',
#    'catP',
#    'erm(B)',
#    'vanRB',
#    'pikR2',
#    'blaCARB',
#    'cat',
#    'aadA2a',
#    'blaMOX/blaCMY',
#    'tetJ',
#    'vgaA',
#    'dfrA15',
#    'tetH',
#    'pbrT',
#    'tetA',
#    'blaVIM',
#    "aph(3'')-ia",
#    'strB',
#    'aph6ia',
#    'blaOXA10',
#    'mdth',
#    'dfra21',
#    'cmlA1',
#    'aac(3)-Xab',
#    'vanC',
#    'aac(6)-ij',
#    'tolC',
#    'aadA5',
#    'aac(3)-xaa',
#    'bla-L1',
#    "aac(6')-II",
#    'vatB',
#    'arsA',
#    'ere(A)',
#    'blaPAO/PDC',
#    'mexA',
#    'tetPB',
#    'carB',
#    'bl3_cpha',
#    'mef(B)',
#    'blaCMY',
#    'blaSHV-11',
#    'dfrK',
#    'cefa_ampc',
#    'tetB',
#    'tetL',
#    'sulA/folP',
#    'ttgB',
#    'mefA',
#    'tetS',
#    'vanYB',
#    'msr(C)',
#    'ermX',
#    'blaOCH',
#    'erm(42)',
#    'apmA',
#    'ttgA',
#    'spec_aph',
#    'sugE',
#    'cmlV',
#    'aadA10',
#    'ampC',
#    'ampC/blaDHA',
#    'vgaB',
#    'blaIMIR',
#    'dfrA27',
#    'cfiA',
#    'msr(A)',
#    'erm(A)',
#    'bla1',
#    'vanHB',
#    'aac(6)-iic',
#    'aadA2b'],
#   'traN': ['ttgA',
#    'spec_aph',
#    'sugE',
#    'cmlV',
#    'aadA10',
#    'ampC/blaDHA',
#    'vgaB',
#    'blaIMIR',
#    'dfrA27',
#    'cfiA',
#    'msr(A)',
#    'erm(A)',
#    'bla1',
#    'vanHB',
#    "aac(6')-II",
#    'aadA2b',
#    'erm(35)',
#    'blaLEN',
#    'aadD',
#    'erm(D)',
#    'blaSHV-11',
#    'aac(3)-iid_iii_iif_iia_iie',
#    'tet(38)',
#    'dfrA25',
#    'bexA/norM',
#    'blaCTX-M',
#    'catB9',
#    'sulA/folP',
#    'tetE',
#    'acrR',
#    'sul2',
#    'NDM new',
#    'tetQ',
#    'vanYD',
#    'blaOCH',
#    'vanC2/vanC3',
#    'tetC',
#    'vanHD',
#    'erm(S)',
#    'ampC',
#    'cadC',
#    'qnrS2',
#    'erm(B)',
#    'vanRB',
#    'pikR2',
#    'blaCARB',
#    'cat',
#    'aadA2a',
#    'blaMOX/blaCMY',
#    'tetJ',
#    'vgaA',
#    'dfrA15',
#    'pbrT',
#    'cmlA5',
#    'tetA',
#    'blaVIM',
#    'ermA/ermTR',
#    'tet44',
#    'strB',
#    'norA',
#    'aph6ia',
#    'aadA6',
#    'blaOXA10',
#    'dfra21',
#    'cmlA1',
#    'aac(3)-Xab',
#    'lsa(C)',
#    'vanC',
#    'aac(6)-ij',
#    'aph_viii',
#    'terW',
#    'tolC',
#    'aadA_99',
#    'dfrBmulti',
#    'dfra17',
#    'adeI',
#    'aadA5',
#    'strA',
#    'aac(3)-xaa',
#    'vat(E)',
#    'vatB',
#    'arsA',
#    'ere(A)',
#    'blaPAO/PDC',
#    'mexA',
#    'tetPB',
#    'carB',
#    'mef(B)',
#    'blaCMY',
#    'cmx(A)',
#    'cefa_ampc',
#    'tetB',
#    'tetL',
#    'ttgB',
#    'tetS',
#    'vanYB',
#    'msr(C)',
#    'ermX',
#    'erm(42)',
#    'apmA',
#    'mdth'],
#   'tnpAc': ['ere(A)',
#    'tetPB',
#    'carB',
#    'bl3_cpha',
#    'mef(B)',
#    'cefa_ampc',
#    'tetB',
#    'tetL',
#    'ttgB',
#    'tetA',
#    'mefA',
#    'tetS',
#    'vanYB',
#    'msr(C)',
#    'aadB',
#    'ermX',
#    'erm(42)',
#    'mdth',
#    'cmlA1',
#    'spec_aph',
#    'sugE',
#    'cmlV',
#    'ampC/blaDHA',
#    'vgaB',
#    'blaIMIR',
#    'dfrA27',
#    'cfiA',
#    'msr(A)',
#    'erm(A)',
#    'bla1',
#    'vanHB',
#    'bla-L1',
#    "aac(6')-II",
#    'vatB',
#    'aadA2b',
#    'pbp',
#    'erm(35)',
#    'aadD',
#    'erm(D)',
#    'dfrA25',
#    'bexA/norM',
#    'blaCTX-M',
#    'sulA/folP',
#    'tetE',
#    'acrR',
#    'NDM new',
#    'tetQ',
#    'blaOCH',
#    'apmA',
#    'vanC2/vanC3',
#    'tetC',
#    'blaIMI',
#    'erm(S)',
#    'ampC',
#    'catP',
#    'erm(B)',
#    'vanRB',
#    'cat',
#    'blaMOX/blaCMY',
#    'tetJ',
#    'vgaA',
#    'dfrA15',
#    'tetH',
#    'catB9',
#    'blaVIM',
#    'sul2',
#    "aph(3'')-ia",
#    'tet44',
#    'strB',
#    'aadA6',
#    'blaOXA10',
#    'vanC',
#    'aac(6)-ij',
#    'tolC',
#    'adeI',
#    'aadA5',
#    'blaCARB',
#    'aac(3)-xaa',
#    'aadA2a'],
#   'IncN_rep': ['erm(S)',
#    'VanB',
#    'ampC',
#    'blaFOXnew',
#    'cadC',
#    'qnrS2',
#    'catP',
#    'mdtE/yhiU',
#    'pikR2',
#    'lnu(F)',
#    'blaCARB',
#    'mexE',
#    'cat',
#    'blaMOX/blaCMY',
#    'dfrA15',
#    'vanRC',
#    'pbrT',
#    'cmlA5',
#    'blaVIM',
#    'sul2',
#    "aph(3'')-ia",
#    'tet44',
#    'strB',
#    'norA',
#    'aph6ia',
#    'blaOXA10',
#    'dfra21',
#    'cmlA1',
#    'aac(3)-Xab',
#    'dfra14',
#    'lsa(C)',
#    'vanC',
#    'QnrVC1_VC3_VC6',
#    'dfrA10',
#    'aac(6)-ij',
#    'aph_viii',
#    'merA-marko',
#    'terW',
#    'dfrBmulti',
#    'dfra17',
#    'adeI',
#    'aac(3)-xaa',
#    'bla-L1',
#    'aadA17',
#    'aadA2a',
#    'vatB',
#    'arsA',
#    'blaPAO/PDC',
#    'mexA',
#    'tetPB',
#    'carB',
#    'bl3_cpha',
#    'mef(B)',
#    'acrB',
#    'blaCMY',
#    'dfrK',
#    'cefa_ampc',
#    'ttgB',
#    'tetA',
#    'tetS',
#    'msr(C)',
#    'ermX',
#    'ArmA',
#    'vanSB',
#    'erm(42)',
#    'mdth',
#    'ttgA',
#    'sul1 NEW',
#    'Aac6-Aph2',
#    'sugE',
#    'aadA10',
#    'vgaB',
#    'blaIMIR',
#    'dfrA27',
#    'aac(6)-iv_ih',
#    'mtrD',
#    'aadA2b',
#    'erm(35)',
#    'blaLEN',
#    'acc3-iva',
#    'mepA',
#    'aadD',
#    'blaSHV-11',
#    'aac(3)-iid_iii_iif_iia_iie',
#    'cmx(A)',
#    'dfrA25',
#    'bexA/norM',
#    'blaCTX-M',
#    'catB9',
#    'acrR',
#    'NDM new',
#    'vanYD',
#    'blaOCH',
#    'aphA1',
#    'tetC',
#    'vanHD'],
#   'EAE_05855': ['qnrS2',
#    'catP',
#    'erm(B)',
#    'vanRB',
#    'blaPSE',
#    'pikR2',
#    'blaCARB',
#    'mexE',
#    'cat',
#    'beta_ccra',
#    'ceoA',
#    'blaMOX/blaCMY',
#    'tetJ',
#    'vgaA',
#    'dfrA15',
#    'vanRC',
#    'pbrT',
#    'cmlA5',
#    'blaVIM',
#    'sul2',
#    'erm(F)a',
#    "aph(3'')-ia",
#    'tet44',
#    'strB',
#    'norA',
#    'aph6ia',
#    'aadA6',
#    'blaOXA10',
#    'dfra21',
#    'cmlA1',
#    'aac(3)-Xab',
#    'lsa(C)',
#    'vanC',
#    'QnrVC1_VC3_VC6',
#    'dfrA10',
#    'aac(6)-ij',
#    'aph_viii',
#    'terW',
#    'blaHERA',
#    'tolC',
#    'dfrBmulti',
#    'dfra17',
#    'aadA5',
#    'aac(3)-xaa',
#    'bla-L1',
#    'aadA17',
#    'aadA2a',
#    'vatB',
#    'arsA',
#    'blaPAO/PDC',
#    'mexA',
#    'tetPB',
#    'carB',
#    'bl3_cpha',
#    'mef(B)',
#    'blaCMY',
#    'dfrK',
#    'cefa_ampc',
#    'tetB',
#    'tetL',
#    'ttgB',
#    'tetA',
#    'pica',
#    'tetS',
#    'vanYB',
#    'msr(C)',
#    'ermX',
#    'ArmA',
#    'vanSB',
#    'erm(42)',
#    'apmA',
#    'mdth',
#    'ttgA',
#    'spec_aph',
#    'sugE',
#    'cmlV',
#    'aadA10',
#    'cfxA',
#    'ampC/blaDHA',
#    'vgaB',
#    'blaIMIR',
#    'dfrA27',
#    'cfiA',
#    'msr(A)',
#    'erm(A)',
#    'vanHB',
#    'aac(6)-iv_ih',
#    'mtrD',
#    "aac(6')-II",
#    'cepA',
#    'aadA2b',
#    'pbp',
#    'erm(35)',
#    'blaLEN',
#    'mepA',
#    'aadD',
#    'erm(D)',
#    'blaSHV-11',
#    'aac(3)-iid_iii_iif_iia_iie',
#    'cmx(A)',
#    'dfrA25',
#    'bexA/norM',
#    'blaCTX-M',
#    'catB9',
#    'tetE',
#    'acrR',
#    'NDM new',
#    'vanYD',
#    'blaOCH',
#    'vanC2/vanC3',
#    'aphA1',
#    "aac(6')-Ib",
#    'tetC',
#    'vanHD',
#    'erm(S)',
#    'VanB',
#    'ampC',
#    'blaFOXnew',
#    'cadC'],
#   'lncF_FIC': ['sul1 NEW', 'acrA', 'vanSC', 'ant4-ib', 'vanRC', 'vanRC4'],
#   'IS6100': ['aac(3)-id_ie',
#    'blaOXA10',
#    'tolC',
#    'marR',
#    'aac(6)-iz',
#    'vat(A)',
#    "aac(6')I1",
#    'tet(32)',
#    'cmlV',
#    'adeA',
#    'erm(F)b',
#    'cfiA',
#    'aac(6)-iw',
#    'dfrA25',
#    'tet44',
#    'erm(B)',
#    'vanRB',
#    'aac(6)-ir',
#    'catA3',
#    'blaACC-1',
#    'vanTG'],
#   'ISEfm1-Entero': ["aac(6')-II",
#    'blaLEN',
#    'aadD',
#    'erm(D)',
#    'dfrA25',
#    'blaOCH',
#    'apmA',
#    'vanC2/vanC3',
#    'cmlV',
#    'ampC',
#    'blaIMIR',
#    'cfiA',
#    'aac(6)-iw',
#    'catA3',
#    'cat',
#    'tetJ',
#    'vgaA',
#    'tetE',
#    'vanTG',
#    "aph(3'')-ia",
#    'aac(3)-id_ie',
#    'tet44',
#    'strB',
#    'aadA6',
#    'blaOXA10',
#    'tolC',
#    'erm(B)',
#    'adeI',
#    'vanRB',
#    'aadA5',
#    'blaCARB',
#    'aac(3)-xaa',
#    'blaMOX/blaCMY',
#    'ere(A)',
#    'tetPB',
#    'carB',
#    'bl3_cpha',
#    'dfrA15',
#    'cefa_ampc',
#    'tetB',
#    'tetL',
#    'tetS',
#    'vanYB',
#    'erm(42)',
#    'mdth',
#    "aac(6')I1",
#    'cmlA1',
#    'spec_aph',
#    'vanC',
#    'sugE',
#    'aac(6)-ij',
#    'ampC/blaDHA',
#    'vgaB',
#    'msr(A)',
#    'erm(A)',
#    'bla-L1'],
#   'orf37-IS26': ['catB3',
#    'qnrB-bob_resign',
#    'strA',
#    'vat(E)',
#    'bla-SME',
#    'aadB',
#    'pica',
#    'qepA_1_2',
#    'ant6-ia',
#    'tetR',
#    "aac(6')-Ib",
#    'blaIMI',
#    'blaGES',
#    'blaPSE'],
#   'IS630': ['aac(3)-iid_iii_iif_iia_iie',
#    'bexA/norM',
#    'blaCTX-M',
#    'pbrT',
#    'catB9',
#    'cmlA5',
#    'blaVIM',
#    'sul2',
#    "aph(3'')-ia",
#    'vanYD',
#    'tet44',
#    'norA',
#    'aph6ia',
#    'blaOXA10',
#    'vanHD',
#    'dfra21',
#    'aac(3)-Xab',
#    'VanB',
#    'cadC',
#    'merA-marko',
#    'dfrBmulti',
#    'dfra17',
#    'adeI',
#    'pikR2',
#    'blaCARB',
#    'aac(3)-xaa',
#    'cat',
#    'aadA2a',
#    'arsA',
#    'blaMOX/blaCMY',
#    'carB',
#    'bl3_cpha',
#    'mef(B)',
#    'dfrA15',
#    'dfrK',
#    'cefa_ampc',
#    'ttgB',
#    'tetA',
#    'vanWB',
#    'ArmA',
#    'vanSB',
#    'erm(42)',
#    'mdth',
#    'lsa(C)',
#    'QnrVC1_VC3_VC6',
#    'sugE',
#    'aadA10',
#    'dfrA10',
#    'vgaB',
#    'aph_viii',
#    'terW',
#    'bla-L1',
#    'aac(6)-iv_ih',
#    "aac(6')-II",
#    'vatB',
#    'blaPAO/PDC',
#    'aac(6)-im',
#    'mexA',
#    'erm(35)',
#    'blaLEN',
#    'acrB',
#    'blaCMY',
#    'penA',
#    'erm(D)',
#    'blaSHV-11',
#    'cmx(A)',
#    'acrR',
#    'NDM new',
#    'msr(C)',
#    'ermX',
#    'blaOCH',
#    'ttgA',
#    'tetC',
#    'ampC',
#    'ampC/blaDHA',
#    'blaFOXnew',
#    'blaIMIR',
#    'dfrA27',
#    'cfiA',
#    'qnrS2',
#    'catP',
#    'mtrD',
#    'mexE',
#    'aadA2b'],
#   'trfa': ['dfrBmulti',
#    'mdtE/yhiU',
#    'dfra17',
#    'adeI',
#    'aadA5',
#    'blaCARB',
#    'strA',
#    'aac(3)-xaa',
#    'aadA17',
#    'aadA2a',
#    'arsA',
#    'mexA',
#    'tetPB',
#    'carB',
#    'bl3_cpha',
#    'mef(B)',
#    'blaCMY',
#    'dfrK',
#    'cefa_ampc',
#    'tetB',
#    'ttgB',
#    'tetA',
#    'pica',
#    'tetS',
#    'vanYB',
#    'msr(C)',
#    'ArmA',
#    'vanSB',
#    'erm(42)',
#    'mdth',
#    'sul1 NEW',
#    'cmlA1',
#    'spec_aph',
#    'lsa(C)',
#    'Aac6-Aph2',
#    'sugE',
#    'cmlV',
#    'aadA10',
#    'dfrA10',
#    'ampC/blaDHA',
#    'vgaB',
#    'terW',
#    'blaIMIR',
#    'dfrA27',
#    'cfiA',
#    'msr(A)',
#    'erm(A)',
#    'bla-L1',
#    'aac(6)-iv_ih',
#    'mtrD',
#    "aac(6')-II",
#    'vatB',
#    'aadA2b',
#    'blaPAO/PDC',
#    'erm(35)',
#    'blaLEN',
#    'acc3-iva',
#    'mepA',
#    'aadD',
#    'erm(D)',
#    'blaSHV-11',
#    'tet(38)',
#    'cmx(A)',
#    'dfrA25',
#    'bexA/norM',
#    'blaCTX-M',
#    'tetE',
#    'acrR',
#    'NDM new',
#    'ermX',
#    'vanYD',
#    'blaOCH',
#    'apmA',
#    'vanC2/vanC3',
#    'ttgA',
#    "aac(6')-Ib",
#    'tetC',
#    'erm(S)',
#    'VanB',
#    'ampC',
#    'blaFOXnew',
#    'blaGES',
#    'qnrS2',
#    'catP',
#    'erm(B)',
#    'blaPSE',
#    'pikR2',
#    'mexE',
#    'cat',
#    'blaMOX/blaCMY',
#    'tetJ',
#    'vgaA',
#    'dfrA15',
#    'aac(3)-iid_iii_iif_iia_iie',
#    'pbrT',
#    'catB9',
#    'cmlA5',
#    'blaVIM',
#    'sul2',
#    "aph(3'')-ia",
#    'tet44',
#    'strB',
#    'norA',
#    'aph6ia',
#    'blaOXA10',
#    'ere(B)',
#    'vanHD',
#    'dfra21',
#    'aac(3)-Xab',
#    'dfra14',
#    'vanC',
#    'QnrVC1_VC3_VC6',
#    'aac(6)-ij',
#    'cadC',
#    'aph_viii',
#    'tolC'],
#   'IncQ_oriT': ['tolC',
#    'adeI',
#    'aadA5',
#    'aac(3)-xaa',
#    'ere(A)',
#    'tetPB',
#    'carB',
#    'bl3_cpha',
#    'mef(B)',
#    'cefa_ampc',
#    'tetB',
#    'tetL',
#    'sulA/folP',
#    'tetS',
#    'vanYB',
#    'ermX',
#    'erm(42)',
#    'apmA',
#    'mdth',
#    'spec_aph',
#    'sugE',
#    'cmlV',
#    'ampC/blaDHA',
#    'vgaB',
#    'blaIMIR',
#    'cfiA',
#    'msr(A)',
#    'erm(A)',
#    'bla1',
#    'erm(34)',
#    "aac(6')-II",
#    'erm(35)',
#    'blaLEN',
#    'aadD',
#    'erm(D)',
#    'dfrA25',
#    'bexA/norM',
#    'blaCTX-M',
#    'catB9',
#    'tetE',
#    'sul2',
#    'tetQ',
#    'blaOCH',
#    'vanC2/vanC3',
#    'tetC',
#    'ampC',
#    'erm(B)',
#    'vanRB',
#    'aac(6)-iic',
#    'blaCARB',
#    'cat',
#    'aadA2a',
#    'blaMOX/blaCMY',
#    'tetJ',
#    'vgaA',
#    'dfrA15',
#    "aph(3'')-ia",
#    'tet44',
#    'strB',
#    'aadA6',
#    'blaOXA10',
#    'cmlA1',
#    'vanC',
#    'aac(6)-ij'],
#   'IS1247': ['tetS',
#    'NDM new',
#    'msr(C)',
#    'ermX',
#    'blaOCH',
#    'erm(42)',
#    'vanC2/vanC3',
#    'aphA1',
#    'ttgA',
#    'Aac6-Aph2',
#    'cmlV',
#    'cfxA',
#    'ampC',
#    'ampC/blaDHA',
#    'blaIMIR',
#    'dfrA27',
#    'cfiA',
#    'catP',
#    'mtrD',
#    'mexE',
#    'aadA2b',
#    'erm(35)',
#    'acc3-iva',
#    'mepA',
#    'aadD',
#    'aac(3)-iid_iii_iif_iia_iie',
#    'bexA/norM',
#    'blaCTX-M',
#    'catB9',
#    'cmlA5',
#    'acrR',
#    'sul2',
#    "aph(3'')-ia",
#    'vanYD',
#    'tet44',
#    'norA',
#    'aph6ia',
#    'blaOXA10',
#    'tetC',
#    'vanHD',
#    'dfra21',
#    'aac(3)-Xab',
#    'erm(S)',
#    'VanB',
#    'blaFOXnew',
#    'cadC',
#    'qnrS2',
#    'dfrBmulti',
#    'erm(B)',
#    'dfra17',
#    'adeI',
#    'pikR2',
#    'blaCARB',
#    'aac(3)-xaa',
#    'cat',
#    'aadA2a',
#    'blaMOX/blaCMY',
#    'carB',
#    'bl3_cpha',
#    'dfrA15',
#    'vanRC',
#    'pbrT',
#    'cefa_ampc',
#    'ttgB',
#    'tetA',
#    'blaVIM',
#    'strB',
#    'ArmA',
#    'vanSB',
#    'mdth',
#    'sul1 NEW',
#    'cmlA1',
#    'lsa(C)',
#    'vanC',
#    'QnrVC1_VC3_VC6',
#    'sugE',
#    'aadA10',
#    'dfrA10',
#    'aac(6)-ij',
#    'vgaB',
#    'aph_viii',
#    'merA-marko',
#    'terW',
#    'tolC',
#    'bla-L1',
#    'aadA17',
#    'aac(6)-iv_ih',
#    'vatB',
#    'arsA',
#    'blaPAO/PDC',
#    'mexA',
#    'tetPB',
#    'blaLEN',
#    'mef(B)',
#    'acrB',
#    'blaCMY',
#    'blaSHV-11',
#    'dfrK',
#    'cmx(A)',
#    'dfrA25'],
#   'TN5403': ['pikR2',
#    'mtrD',
#    'mexE',
#    'cat',
#    'aadA2b',
#    'dfrA15',
#    'aac(3)-iid_iii_iif_iia_iie',
#    'pbrT',
#    'catB9',
#    'cmlA5',
#    'blaVIM',
#    'sul2',
#    "aph(3'')-ia",
#    'norA',
#    'aph6ia',
#    'erm(E)',
#    'vanHD',
#    'dfra21',
#    'aac(3)-Xab',
#    'cadC',
#    'aph_viii',
#    'dfrBmulti',
#    'dfra17',
#    'blaCARB',
#    'aac(3)-xaa',
#    'aadA17',
#    'aadA2a',
#    'arsA',
#    'mexA',
#    'mef(B)',
#    'acrB',
#    'blaCMY',
#    'dfrK',
#    'cefa_ampc',
#    'ttgB',
#    'tetA',
#    'msr(C)',
#    'ArmA',
#    'vanSB',
#    'erm(42)',
#    'mdth',
#    'lsa(C)',
#    'mexB',
#    'QnrVC1_VC3_VC6',
#    'sugE',
#    'aadA10',
#    'dfrA10',
#    'vgaB',
#    'terW',
#    'dfrA27',
#    'vanHB',
#    'bla-L1',
#    'aac(6)-iv_ih',
#    'vatB',
#    'blaPAO/PDC',
#    'erm(35)',
#    'mepA',
#    'blaSHV-11',
#    'cmx(A)',
#    'bexA/norM',
#    'blaCTX-M',
#    'NDM new',
#    'ermX',
#    'vanYD',
#    'aac3-Via',
#    'aphA1',
#    'ttgA',
#    'tetC',
#    'VanB',
#    'blaFOXnew',
#    'qnrS2',
#    'catP'],
#   'IS26': ['tet39', 'cat(pC221)', 'aadE', 'blaVEB'],
#   'tnpAg': ['blaOCH',
#    'erm(42)',
#    'apmA',
#    "aac(6')I1",
#    'spec_aph',
#    'sugE',
#    'cmlV',
#    'ampC',
#    'ampC/blaDHA',
#    'vgaB',
#    'blaIMIR',
#    'cfiA',
#    'erm(A)',
#    'aac(6)-iw',
#    'blaLEN',
#    'tetJ',
#    'aadD',
#    'erm(D)',
#    'dfrA25',
#    'tetE',
#    'vanTG',
#    'tet44',
#    'aadA6',
#    'vanC2/vanC3',
#    'blaOXA10',
#    'vanYB',
#    'erm(B)',
#    'adeI',
#    'vanRB',
#    'blaCARB',
#    'catA3',
#    'cat',
#    'blaMOX/blaCMY',
#    'bl3_cpha',
#    'vgaA',
#    'dfrA15',
#    'cefa_ampc',
#    "aph(3'')-ia",
#    'aac(3)-id_ie',
#    'strB',
#    'mdth',
#    'cmlA1',
#    'vanC',
#    'aac(6)-ij',
#    'tolC',
#    'msr(A)',
#    'aadA5',
#    'aac(3)-xaa',
#    'bla-L1',
#    "aac(6')-II",
#    'ere(A)',
#    'tetPB',
#    'carB',
#    'tetB',
#    'tetL',
#    'tetS'],
#   'fabK': ['vgaB',
#    'blaIMIR',
#    'bla1',
#    'blaPSE',
#    'pbp',
#    'erm(35)',
#    'aadD',
#    'acrF',
#    'bexA/norM',
#    'blaCTX-M',
#    'catB9',
#    'sul2',
#    'ant6-ia',
#    'tetR',
#    'tetQ',
#    'catB3',
#    'qnrB-bob_resign',
#    "aac(6')-Ib",
#    'tetC',
#    'blaIMI',
#    'blaGES',
#    'strA',
#    'cat',
#    'aadA2a',
#    'blaMOX/blaCMY',
#    'dfrA15',
#    'tetH',
#    'cefa_ampc',
#    'aadB',
#    'mdth',
#    'cmlA1',
#    'aac(6)-ij',
#    'aadA_99',
#    'vat(E)',
#    'bla-SME',
#    'tetPB',
#    'carB',
#    'mef(B)',
#    'sulA/folP',
#    'pica',
#    'mefA',
#    'ermX',
#    'sugE'],
#   'Arr2': ['tetJ',
#    'aadD',
#    'aac(3)-iid_iii_iif_iia_iie',
#    'bexA/norM',
#    'blaCTX-M',
#    'pbrT',
#    'catB9',
#    'cmlA5',
#    'blaACC-1',
#    'tetE',
#    'vanTG',
#    'blaVIM',
#    'sul2',
#    "aph(3'')-ia",
#    'vanYD',
#    'tet44',
#    'norA',
#    'blaOXA10',
#    'vanHD',
#    'dfra21',
#    'cadC',
#    'dfrBmulti',
#    'erm(B)',
#    'dfra17',
#    'adeI',
#    'vanRB',
#    'aadA5',
#    'pikR2',
#    'blaCARB',
#    'cat',
#    'aadA2a',
#    'blaMOX/blaCMY',
#    'ere(A)',
#    'tetPB',
#    'carB',
#    'mef(B)',
#    'vgaA',
#    'dfrA15',
#    'cefa_ampc',
#    'tetB',
#    'ttgB',
#    'tetA',
#    'vanYB',
#    'aac(3)-id_ie',
#    'ArmA',
#    'vanSB',
#    'erm(42)',
#    'spec_aph',
#    'lsa(C)',
#    'vanC',
#    'QnrVC1_VC3_VC6',
#    'sugE',
#    'adeA',
#    'aadA10',
#    'dfrA10',
#    'aac(6)-ij',
#    'vgaB',
#    'aph_viii',
#    'terW',
#    'tolC',
#    'msr(A)',
#    'erm(A)',
#    'bla-L1',
#    'aac(6)-iv_ih',
#    "aac(6')-II",
#    'vatB',
#    'mexA',
#    'erm(35)',
#    'blaLEN',
#    'blaCMY',
#    'erm(D)',
#    'cmx(A)',
#    'dfrA25',
#    'tetS',
#    'msr(C)',
#    'ermX',
#    'vat(A)',
#    'blaOCH',
#    'apmA',
#    'vanC2/vanC3',
#    'ttgA',
#    'tetC',
#    'cmlV',
#    'ampC',
#    'ampC/blaDHA',
#    'blaIMIR',
#    'dfrA27',
#    'cfiA',
#    'qnrS2',
#    'catP',
#    'aac(6)-ir',
#    'aac(6)-iw',
#    'catA3',
#    'mtrD',
#    'mexE',
#    'aadA2b'],
#   'dfrA1': ['qacA/B',
#    'blaROB',
#    'ampC',
#    'blaIMIR',
#    'catP',
#    'mtrD',
#    'mexE',
#    'penA',
#    'catB9',
#    'cmlA5',
#    'vanHD',
#    'qnrS2',
#    'adeI',
#    'aadA2a',
#    'blaVIM',
#    'vanWB',
#    "aph(3'')-ia",
#    'vanSB',
#    'QnrVC1_VC3_VC6',
#    'vatB',
#    'aac(6)-im',
#    'mexA',
#    'cmx(A)',
#    'QnrS1_S3_S5',
#    'ermX'],
#   'fosb': ['adeA',
#    'aac(6)-iw',
#    'marR',
#    'folA',
#    'catA3',
#    'vanG',
#    'aac(3)-id_ie',
#    "aac(6')I1",
#    'tet(32)'],
#   'IS200b': ['vanHD',
#    'dfra21',
#    'aac(3)-Xab',
#    'dfra14',
#    'VanB',
#    'cadC',
#    'merA-marko',
#    'dfrBmulti',
#    'mdtE/yhiU',
#    'dfra17',
#    'adeI',
#    'pikR2',
#    'lnu(F)',
#    'blaCARB',
#    'aac(3)-xaa',
#    'cat',
#    'aadA2a',
#    'arsA',
#    'blaMOX/blaCMY',
#    'tetPB',
#    'carB',
#    'bl3_cpha',
#    'mef(B)',
#    'dfrA15',
#    'dfrK',
#    'cefa_ampc',
#    'ttgB',
#    'tetA',
#    'ArmA',
#    'vanSB',
#    'erm(42)',
#    'mdth',
#    'sul1 NEW',
#    'cmlA1',
#    'lsa(C)',
#    'QnrVC1_VC3_VC6',
#    'sugE',
#    'aadA10',
#    'dfrA10',
#    'aac(6)-ij',
#    'vgaB',
#    'aph_viii',
#    'terW',
#    'bla-L1',
#    'aadA17',
#    'aac(6)-iv_ih',
#    'vatB',
#    'blaPAO/PDC',
#    'mexA',
#    'erm(35)',
#    'blaLEN',
#    'acc3-iva',
#    'blaCMY',
#    'blaSHV-11',
#    'cmx(A)',
#    'tetS',
#    'NDM new',
#    'msr(C)',
#    'ermX',
#    'aphA1',
#    'ttgA',
#    'tetC',
#    'ampC',
#    'blaFOXnew',
#    'dfrA27',
#    'qnrS2',
#    'catP',
#    'mtrD',
#    'mexE',
#    'aadA2b',
#    'aadD',
#    'aac(3)-iid_iii_iif_iia_iie',
#    'bexA/norM',
#    'blaCTX-M',
#    'pbrT',
#    'catB9',
#    'cmlA5',
#    'blaVIM',
#    'sul2',
#    "aph(3'')-ia",
#    'vanYD',
#    'strB',
#    'norA',
#    'aph6ia'],
#   'tnpAb': ['aac(3)-xaa',
#    'bl3_cpha',
#    'floR',
#    'erm(34)',
#    'aac(3)-ib',
#    'vanTC',
#    'tetU',
#    'QnrB4',
#    'aphA3',
#    'aac(6)-iic'],
#   'orf39-IS26': ['blaHERA',
#    'cepA',
#    'pica',
#    "aac(6')-Ib",
#    'blaPSE',
#    'catB3',
#    'mefA'],
#   'IS6/257': ['spec_aph',
#    'floR',
#    'msr(A)',
#    'erm(34)',
#    'aphA3',
#    'aac(3)-ib',
#    'vanTC',
#    'tetU',
#    'aac(6)-iic',
#    'vgaA',
#    'catB8',
#    'qacH_351',
#    'blaGOB'],
#   'fosX': ['strB',
#    'cmlA1',
#    'aac(6)-ij',
#    'aac(3)-xaa',
#    'bl3_cpha',
#    'silE',
#    'floR',
#    'erm(34)',
#    'aphA3',
#    'aac(6)-iic',
#    'aac(3)-ib',
#    'vanTC',
#    'tetU',
#    'QnrB4',
#    'blaGOB'],
#   'IS1133': ['aac(3)-xaa',
#    'bl3_cpha',
#    'bl1acc',
#    'floR',
#    'erm(34)',
#    'aphA3',
#    'aac(3)-ib',
#    'vanTC',
#    'tetU',
#    'QnrB4',
#    'aac(6)-iic'],
#   'ISSm2-Xanthob': ['qnrB-bob_resign', 'mphA', 'pica', "aac(6')-Ib", 'blaPSE'],
#   'ISCR1': ['vanTE', 'blaTEM', 'catB8', 'qacH_351'],
#   'IS91': ['ampC/blaDHA', 'vanHB', 'mepA', 'ere(A)', 'erm(E)'],
#   'ISPps1-pseud': ['erm(34)', 'vanTC', 'tetU', 'blaGOB', 'aac(6)-iic'],
#   'mobA': ['lnuB', 'oqxA', 'qnrA', 'vga(A)LC', 'tetW', 'tetbP'],
#   'intI1F165_clinical': ['tetL'],
#   'IS21-ISAs29': ['vanRC4', 'ant4-ib', 'acrA']},
#  'control_ex_corrs': {'Arr2': ['sulA/folP',
#    'catA1',
#    'merA-marko',
#    'cefa_qacelta',
#    'QnrS1_S3_S5',
#    'aadE',
#    'erm(Q)',
#    'lnu(F)',
#    'tetH',
#    'vat(E)',
#    'erm(F)b',
#    'cfxA',
#    'QnrB4',
#    'bla-SME',
#    'tetX',
#    'blaHERA',
#    'erm(F)a',
#    'aadA_99',
#    'blaIMI',
#    'ant6-ib',
#    'vanXA',
#    'qacF/Ha',
#    'vga(A)LC',
#    'lnuB',
#    'blaGES',
#    'aac(6)-is_iu_ix',
#    'tcrB',
#    'vanWB',
#    'mefA',
#    'vanA',
#    'ermA/ermTR',
#    'ermY',
#    'bl1acc',
#    'vanRD',
#    'tet39'],
#   'IS26': ['bl1acc',
#    'vanRD',
#    'aac(6)-iw',
#    'catA3',
#    'mtrD',
#    'aadA2b',
#    'sulA/folP',
#    'catA1',
#    'merA-marko',
#    'cefa_qacelta',
#    'tetS',
#    'QnrS1_S3_S5',
#    'lsa(C)',
#    'aadD',
#    'erm(B)',
#    'ermX',
#    'vanRB',
#    'blaOCH',
#    'aadA5',
#    'erm(Q)',
#    'pikR2',
#    'lnu(F)',
#    'tetH',
#    'vat(E)',
#    'erm(F)b',
#    'apmA',
#    'dfrA10',
#    'blaCTX-M',
#    'cfxA',
#    'QnrB4',
#    'catB9',
#    'vanC2/vanC3',
#    'vgaB',
#    'aph_viii',
#    'terW',
#    'vanTG',
#    'bla-SME',
#    'tetX',
#    'blaHERA',
#    'sul2',
#    'tetPB',
#    'erm(F)a',
#    'aadA_99',
#    'blaIMI',
#    'vanA',
#    'ant6-ib',
#    'msr(A)',
#    'erm(A)',
#    'vanXA',
#    'qacF/Ha',
#    'vga(A)LC',
#    'ampC/blaDHA',
#    'lnuB',
#    'blaGES',
#    'aac(6)-is_iu_ix',
#    'erm(35)',
#    'blaLEN',
#    'dfra21',
#    'tcrB',
#    'vanWB',
#    'mefA',
#    'ermA/ermTR',
#    'qnrS2',
#    'catP',
#    'ermY',
#    'erm(D)'],
#   'fosb': ['blaHERA',
#    'cefa_qacelta',
#    'aadA_99',
#    'vanXA',
#    'qacF/Ha',
#    'blaOCH',
#    'aadA5',
#    'aadE',
#    'tetH',
#    'vat(E)',
#    'erm(F)b',
#    'cfxA',
#    'QnrB4',
#    'ampC/blaDHA',
#    'vanC2/vanC3',
#    'vgaB',
#    'terW',
#    'vanTG',
#    'bla-SME',
#    'tetX',
#    'sul2',
#    'tetPB',
#    'erm(F)a',
#    'vanWB',
#    'blaIMI',
#    'vanA',
#    'ant6-ib',
#    'ermA/ermTR',
#    'msr(A)',
#    'erm(A)',
#    'vga(A)LC',
#    'bl1acc',
#    'lnuB',
#    'mtrD',
#    'tet39',
#    'aadA2b',
#    'blaGES',
#    'aac(6)-is_iu_ix',
#    'catA1',
#    'erm(35)',
#    'blaLEN',
#    'dfra21',
#    'tcrB',
#    'mefA',
#    'tetS',
#    'QnrS1_S3_S5',
#    'qnrS2',
#    'catP',
#    'lsa(C)',
#    'ermY',
#    'aadD',
#    'erm(B)',
#    'ermX',
#    'erm(D)',
#    'vanRB',
#    'erm(Q)',
#    'pikR2',
#    'vanRD',
#    'lnu(F)',
#    'apmA',
#    'dfrA10',
#    'blaCTX-M',
#    'catB9',
#    'sulA/folP',
#    'aph_viii',
#    'merA-marko'],
#   'ISSm2-Xanthob': ['catA1',
#    'cefa_qacelta',
#    'tetS',
#    'QnrS1_S3_S5',
#    'qnrS2',
#    'lsa(C)',
#    'aadD',
#    'erm(B)',
#    'ermX',
#    'vanRB',
#    'blaOCH',
#    'erm(Q)',
#    'pikR2',
#    'lnu(F)',
#    'catA3',
#    'dfrA10',
#    'apmA',
#    'blaCTX-M',
#    'QnrB4',
#    'catB9',
#    'vanC2/vanC3',
#    'vgaB',
#    'aph_viii',
#    'merA-marko',
#    'terW',
#    'vanTG',
#    'bla-SME',
#    'tetX',
#    'blaHERA',
#    'sul2',
#    'aadA_99',
#    'blaIMI',
#    'msr(A)',
#    'vanXA',
#    'qacF/Ha',
#    'vga(A)LC',
#    'aadA5',
#    'aadE',
#    'tetH',
#    'vat(E)',
#    'erm(F)b',
#    'cfxA',
#    'ampC/blaDHA',
#    'blaGES',
#    'aac(6)-is_iu_ix',
#    'tetPB',
#    'blaLEN',
#    'erm(F)a',
#    'dfra21',
#    'tcrB',
#    'vanWB',
#    'mefA',
#    'vanA',
#    'ant6-ib',
#    'ermA/ermTR',
#    'erm(A)',
#    'catP',
#    'ermY',
#    'erm(D)',
#    'bl1acc',
#    'vanRD',
#    'aac(6)-iw',
#    'lnuB',
#    'mtrD',
#    'tet39',
#    'aadA2b',
#    'sulA/folP'],
#   'IncQ_oriT': ['merA-marko',
#    'terW',
#    'blaHERA',
#    'cefa_qacelta',
#    'aadA_99',
#    'vanXA',
#    'qacF/Ha',
#    'vga(A)LC',
#    'aadE',
#    'tetH',
#    'vat(E)',
#    'erm(F)b',
#    'cfxA',
#    'QnrB4',
#    'vanTG',
#    'aac(6)-is_iu_ix',
#    'bla-SME',
#    'tetX',
#    'erm(F)a',
#    'tcrB',
#    'vanWB',
#    'blaIMI',
#    'vanA',
#    'ant6-ib',
#    'ermA/ermTR',
#    'bl1acc',
#    'aac(6)-iw',
#    'lnuB',
#    'mtrD',
#    'tet39',
#    'aadA2b',
#    'blaGES',
#    'catA1',
#    'dfra21',
#    'mefA',
#    'QnrS1_S3_S5',
#    'qnrS2',
#    'catP',
#    'lsa(C)',
#    'ermY',
#    'erm(Q)',
#    'pikR2',
#    'vanRD',
#    'lnu(F)',
#    'catA3',
#    'dfrA10',
#    'aph_viii'],
#   'IncN_rep': ['blaIMI',
#    'vanA',
#    'ant6-ib',
#    'ermA/ermTR',
#    'msr(A)',
#    'erm(A)',
#    'bl1acc',
#    'aac(6)-iw',
#    'lnuB',
#    'tet39',
#    'blaGES',
#    'aac(6)-is_iu_ix',
#    'catA1',
#    'tcrB',
#    'mefA',
#    'QnrS1_S3_S5',
#    'ermY',
#    'erm(B)',
#    'erm(D)',
#    'vanRB',
#    'erm(Q)',
#    'vanRD',
#    'catA3',
#    'apmA',
#    'sulA/folP',
#    'blaHERA',
#    'cefa_qacelta',
#    'copA',
#    'aadA_99',
#    'vanXA',
#    'qacF/Ha',
#    'vga(A)LC',
#    'aadA5',
#    'aadE',
#    'tetH',
#    'vat(E)',
#    'erm(F)b',
#    'cfxA',
#    'QnrB4',
#    'ampC/blaDHA',
#    'vanC2/vanC3',
#    'vanTG',
#    'bla-SME',
#    'tetX',
#    'erm(F)a',
#    'vanWB'],
#   'fabK': ['vga(A)LC',
#    'aadA5',
#    'aadE',
#    'erm(F)b',
#    'cfxA',
#    'QnrB4',
#    'ampC/blaDHA',
#    'vanC2/vanC3',
#    'vanTG',
#    'aac(6)-is_iu_ix',
#    'erm(F)a',
#    'dfra21',
#    'tcrB',
#    'vanWB',
#    'vanA',
#    'ant6-ib',
#    'ermA/ermTR',
#    'msr(A)',
#    'erm(A)',
#    'bl1acc',
#    'aac(6)-iw',
#    'lnuB',
#    'mtrD',
#    'tet39',
#    'aadA2b',
#    'catA1',
#    'blaLEN',
#    'tetS',
#    'QnrS1_S3_S5',
#    'qnrS2',
#    'catP',
#    'lsa(C)',
#    'ermY',
#    'erm(B)',
#    'erm(D)',
#    'vanRB',
#    'blaOCH',
#    'erm(Q)',
#    'pikR2',
#    'vanRD',
#    'lnu(F)',
#    'catA3',
#    'apmA',
#    'dfrA10',
#    'aph_viii',
#    'merA-marko',
#    'terW',
#    'tetX',
#    'blaHERA',
#    'cefa_qacelta',
#    'copA',
#    'vanXA',
#    'qacF/Ha'],
#   'ISAba3-Acineto': ['ermY',
#    'bl1acc',
#    'vanRD',
#    'aac(6)-iw',
#    'lnuB',
#    'tet39',
#    'sulA/folP',
#    'catA1',
#    'cefa_qacelta',
#    'QnrS1_S3_S5',
#    'erm(B)',
#    'vanRB',
#    'blaOCH',
#    'erm(Q)',
#    'lnu(F)',
#    'catA3',
#    'QnrB4',
#    'vanC2/vanC3',
#    'merA-marko',
#    'vanTG',
#    'bla-SME',
#    'tetX',
#    'blaHERA',
#    'aadA_99',
#    'blaIMI',
#    'msr(A)',
#    'vanXA',
#    'qacF/Ha',
#    'vga(A)LC',
#    'aadA5',
#    'aadE',
#    'tetH',
#    'vat(E)',
#    'erm(F)b',
#    'cfxA',
#    'blaGES',
#    'aac(6)-is_iu_ix',
#    'erm(F)a',
#    'tcrB',
#    'vanWB',
#    'mefA',
#    'vanA',
#    'ant6-ib',
#    'ermA/ermTR',
#    'erm(A)'],
#   'IncHI2-smr0018': ['ermA/ermTR',
#    'ermY',
#    'erm(D)',
#    'bl1acc',
#    'erm(Q)',
#    'vanRD',
#    'aac(6)-iw',
#    'catA3',
#    'tet39',
#    'sulA/folP',
#    'catA1',
#    'cefa_qacelta',
#    'QnrS1_S3_S5',
#    'copA',
#    'erm(B)',
#    'vanRB',
#    'blaOCH',
#    'aadA5',
#    'aadE',
#    'tetH',
#    'vat(E)',
#    'erm(F)b',
#    'apmA',
#    'cfxA',
#    'QnrB4',
#    'ampC/blaDHA',
#    'vanC2/vanC3',
#    'vanTG',
#    'bla-SME',
#    'tetX',
#    'blaHERA',
#    'erm(F)a',
#    'aadA_99',
#    'blaIMI',
#    'vanA',
#    'ant6-ib',
#    'msr(A)',
#    'erm(A)',
#    'vanXA',
#    'qacF/Ha',
#    'vga(A)LC',
#    'lnuB',
#    'blaGES',
#    'aac(6)-is_iu_ix',
#    'tcrB',
#    'vanWB',
#    'mefA'],
#   'tnpAg': ['lsa(C)',
#    'ermY',
#    'ermX',
#    'erm(Q)',
#    'pikR2',
#    'vanRD',
#    'lnu(F)',
#    'dfrA10',
#    'blaCTX-M',
#    'QnrB4',
#    'catB9',
#    'aph_viii',
#    'merA-marko',
#    'terW',
#    'tetX',
#    'blaHERA',
#    'sul2',
#    'aadA_99',
#    'blaIMI',
#    'vanXA',
#    'qacF/Ha',
#    'vga(A)LC',
#    'aadE',
#    'tetH',
#    'vat(E)',
#    'erm(F)b',
#    'cfxA',
#    'aac(6)-is_iu_ix',
#    'bla-SME',
#    'erm(F)a',
#    'dfra21',
#    'tcrB',
#    'vanWB',
#    'mefA',
#    'vanA',
#    'ant6-ib',
#    'ermA/ermTR',
#    'catP',
#    'bl1acc',
#    'lnuB',
#    'mtrD',
#    'tet39',
#    'aadA2b',
#    'sulA/folP',
#    'blaGES',
#    'catA1',
#    'cefa_qacelta',
#    'QnrS1_S3_S5',
#    'copA',
#    'qnrS2'],
#   'tnpAf': ['ermA/ermTR',
#    'ermY',
#    'erm(Q)',
#    'vanRD',
#    'catA3',
#    'mtrD',
#    'tet39',
#    'catA1',
#    'merA-marko',
#    'blaHERA',
#    'cefa_qacelta',
#    'QnrS1_S3_S5',
#    'copA',
#    'aadE',
#    'lnu(F)',
#    'tetH',
#    'vat(E)',
#    'erm(F)b',
#    'cfxA',
#    'QnrB4',
#    'terW',
#    'vanTG',
#    'bla-SME',
#    'tetX',
#    'erm(F)a',
#    'vanWB',
#    'blaIMI',
#    'vanA',
#    'ant6-ib',
#    'vanXA',
#    'qacF/Ha',
#    'vga(A)LC',
#    'bl1acc',
#    'aac(6)-iw',
#    'lnuB',
#    'blaGES',
#    'aac(6)-is_iu_ix',
#    'blaLEN',
#    'tcrB',
#    'mefA'],
#   'int1-a-marko': ['ermY',
#    'erm(Q)',
#    'vanRD',
#    'catA3',
#    'tet39',
#    'sulA/folP',
#    'catA1',
#    'merA-marko',
#    'blaHERA',
#    'cefa_qacelta',
#    'copA',
#    'aadA_99',
#    'qacF/Ha',
#    'aadE',
#    'lnu(F)',
#    'tetH',
#    'vat(E)',
#    'erm(F)b',
#    'cfxA',
#    'QnrB4',
#    'terW',
#    'vanTG',
#    'bla-SME',
#    'tetX',
#    'vanWB',
#    'blaIMI',
#    'vanA',
#    'ant6-ib',
#    'ermA/ermTR',
#    'vanXA',
#    'vga(A)LC',
#    'bl1acc',
#    'aac(6)-iw',
#    'lnuB',
#    'blaGES',
#    'aac(6)-is_iu_ix',
#    'blaLEN',
#    'tcrB',
#    'QnrS1_S3_S5'],
#   'ISEfm1-Entero': ['lnuB',
#    'blaGES',
#    'aac(6)-is_iu_ix',
#    'dfra21',
#    'tcrB',
#    'vanWB',
#    'mefA',
#    'ermA/ermTR',
#    'qnrS2',
#    'catP',
#    'ermY',
#    'bl1acc',
#    'erm(Q)',
#    'vanRD',
#    'mtrD',
#    'blaCTX-M',
#    'tet39',
#    'aadA2b',
#    'sulA/folP',
#    'catA1',
#    'merA-marko',
#    'cefa_qacelta',
#    'QnrS1_S3_S5',
#    'copA',
#    'lsa(C)',
#    'ermX',
#    'aadE',
#    'pikR2',
#    'lnu(F)',
#    'tetH',
#    'vat(E)',
#    'erm(F)b',
#    'dfrA10',
#    'cfxA',
#    'QnrB4',
#    'catB9',
#    'aph_viii',
#    'terW',
#    'bla-SME',
#    'tetX',
#    'blaHERA',
#    'sul2',
#    'erm(F)a',
#    'aadA_99',
#    'blaIMI',
#    'vanA',
#    'ant6-ib',
#    'vanXA',
#    'qacF/Ha',
#    'vga(A)LC'],
#   'TN5': ['aac(6)-is_iu_ix',
#    'blaGES',
#    'blaLEN',
#    'dfra21',
#    'tcrB',
#    'ermA/ermTR',
#    'qnrS2',
#    'ermY',
#    'erm(Q)',
#    'pikR2',
#    'vanRD',
#    'catA3',
#    'mtrD',
#    'tet39',
#    'aph_viii',
#    'catA1',
#    'merA-marko',
#    'blaHERA',
#    'cefa_qacelta',
#    'QnrS1_S3_S5',
#    'lsa(C)',
#    'aadE',
#    'lnu(F)',
#    'vat(E)',
#    'erm(F)b',
#    'dfrA10',
#    'cfxA',
#    'QnrB4',
#    'terW',
#    'vanTG',
#    'bla-SME',
#    'tetX',
#    'erm(F)a',
#    'vanWB',
#    'aadA_99',
#    'vanA',
#    'ant6-ib',
#    'vanXA',
#    'qacF/Ha',
#    'vga(A)LC',
#    'bl1acc',
#    'aac(6)-iw',
#    'lnuB'],
#   'ARR-3': ['erm(Q)',
#    'vanRD',
#    'lnu(F)',
#    'catA3',
#    'merA-marko',
#    'blaHERA',
#    'cefa_qacelta',
#    'copA',
#    'aadA_99',
#    'vanXA',
#    'qacF/Ha',
#    'vga(A)LC',
#    'aadE',
#    'tetH',
#    'vat(E)',
#    'erm(F)b',
#    'cfxA',
#    'QnrB4',
#    'vanTG',
#    'aac(6)-is_iu_ix',
#    'bla-SME',
#    'tetX',
#    'tetPB',
#    'erm(F)a',
#    'tcrB',
#    'blaIMI',
#    'vanA',
#    'ant6-ib',
#    'ermA/ermTR',
#    'bl1acc',
#    'aac(6)-iw',
#    'lnuB',
#    'tet39',
#    'sulA/folP',
#    'blaGES',
#    'catA1',
#    'mefA',
#    'tetS',
#    'QnrS1_S3_S5',
#    'ermY',
#    'aadD']},
#  'shared_corrs': {'ARR-3': ['sul2',
#    'erm(B)',
#    'ermX',
#    'erm(D)',
#    'mtrD',
#    'vanRB',
#    'aadA2b',
#    'pikR2',
#    'vanWB',
#    'apmA',
#    'dfrA10',
#    'blaOCH',
#    'aadA5',
#    'msr(A)',
#    'blaCTX-M',
#    'erm(A)',
#    'catB9',
#    'blaLEN',
#    'dfra21',
#    'aph_viii',
#    'qnrS2',
#    'terW',
#    'catP',
#    'ampC/blaDHA',
#    'vanC2/vanC3',
#    'lsa(C)',
#    'vgaB'],
#   'tnpAg': ['ampC/blaDHA',
#    'vanC2/vanC3',
#    'vgaB',
#    'aadD',
#    'erm(B)',
#    'aac(6)-iw',
#    'erm(D)',
#    'vanRB',
#    'blaOCH',
#    'msr(A)',
#    'tetPB',
#    'catA3',
#    'apmA',
#    'aadA5',
#    'erm(A)',
#    'blaLEN',
#    'tetS',
#    'vanTG'],
#   'fabK': ['blaIMI',
#    'blaCTX-M',
#    'catB9',
#    'tetH',
#    'vat(E)',
#    'mefA',
#    'vgaB',
#    'aadD',
#    'sul2',
#    'ermX',
#    'bla-SME',
#    'aadA_99',
#    'sulA/folP',
#    'tetPB',
#    'blaGES'],
#   'ISAba3-Acineto': ['vgaB',
#    'tetS',
#    'aph_viii',
#    'qnrS2',
#    'terW',
#    'erm(D)',
#    'ampC/blaDHA',
#    'lsa(C)',
#    'aadD',
#    'sul2',
#    'ermX',
#    'mtrD',
#    'aadA2b',
#    'pikR2',
#    'tetPB',
#    'blaLEN',
#    'dfra21',
#    'apmA',
#    'dfrA10',
#    'blaCTX-M',
#    'catB9',
#    'catP'],
#   'ISEfm1-Entero': ['vgaB',
#    'aadD',
#    'vanTG',
#    'erm(D)',
#    'erm(B)',
#    'tetPB',
#    'aac(6)-iw',
#    'catA3',
#    'vanRB',
#    'blaOCH',
#    'aadA5',
#    'msr(A)',
#    'erm(A)',
#    'blaLEN',
#    'tetS',
#    'apmA',
#    'ampC/blaDHA',
#    'vanC2/vanC3'],
#   'IncHI2-smr0018': ['tetS',
#    'aph_viii',
#    'dfrA10',
#    'qnrS2',
#    'merA-marko',
#    'catB9',
#    'catP',
#    'vgaB',
#    'aadD',
#    'terW',
#    'lsa(C)',
#    'sul2',
#    'tetPB',
#    'ermX',
#    'mtrD',
#    'blaCTX-M',
#    'aadA2b',
#    'pikR2',
#    'lnu(F)',
#    'blaLEN',
#    'dfra21'],
#   'tnpAf': ['tetS',
#    'aph_viii',
#    'apmA',
#    'dfrA10',
#    'qnrS2',
#    'catB9',
#    'catP',
#    'ampC/blaDHA',
#    'vanC2/vanC3',
#    'vgaB',
#    'aadD',
#    'erm(D)',
#    'lsa(C)',
#    'vanRB',
#    'sul2',
#    'pikR2',
#    'erm(B)',
#    'tetPB',
#    'ermX',
#    'aadA_99',
#    'blaOCH',
#    'aadA5',
#    'msr(A)',
#    'blaCTX-M',
#    'aadA2b',
#    'erm(A)',
#    'sulA/folP',
#    'dfra21'],
#   'TN5': ['vanRB',
#    'sul2',
#    'erm(B)',
#    'tetPB',
#    'ermX',
#    'blaIMI',
#    'blaOCH',
#    'aadA5',
#    'msr(A)',
#    'blaCTX-M',
#    'aadA2b',
#    'erm(A)',
#    'sulA/folP',
#    'tetH',
#    'mefA',
#    'tetS',
#    'apmA',
#    'catP',
#    'catB9',
#    'ampC/blaDHA',
#    'vanC2/vanC3',
#    'vgaB',
#    'aadD',
#    'erm(D)'],
#   'int1-a-marko': ['catP',
#    'catB9',
#    'ampC/blaDHA',
#    'vanC2/vanC3',
#    'vgaB',
#    'aadD',
#    'erm(D)',
#    'lsa(C)',
#    'vanRB',
#    'sul2',
#    'pikR2',
#    'erm(B)',
#    'tetPB',
#    'ermX',
#    'erm(F)a',
#    'mtrD',
#    'blaOCH',
#    'aadA5',
#    'msr(A)',
#    'blaCTX-M',
#    'aadA2b',
#    'erm(A)',
#    'dfra21',
#    'mefA',
#    'tetS',
#    'aph_viii',
#    'apmA',
#    'dfrA10',
#    'qnrS2'],
#   'IncN_rep': ['dfrA10',
#    'blaOCH',
#    'blaCTX-M',
#    'catB9',
#    'blaLEN',
#    'dfra21',
#    'tetS',
#    'aph_viii',
#    'qnrS2',
#    'merA-marko',
#    'terW',
#    'catP',
#    'lsa(C)',
#    'vgaB',
#    'aadD',
#    'ermX',
#    'mtrD',
#    'aadA2b',
#    'sul2',
#    'pikR2',
#    'lnu(F)',
#    'tetPB'],
#   'Arr2': ['blaLEN',
#    'dfra21',
#    'apmA',
#    'dfrA10',
#    'blaCTX-M',
#    'qnrS2',
#    'catB9',
#    'catP',
#    'vanC2/vanC3',
#    'vgaB',
#    'tetS',
#    'aph_viii',
#    'terW',
#    'vanTG',
#    'ampC/blaDHA',
#    'erm(D)',
#    'lsa(C)',
#    'aadD',
#    'sul2',
#    'erm(B)',
#    'tetPB',
#    'ermX',
#    'aac(6)-iw',
#    'catA3',
#    'mtrD',
#    'vanRB',
#    'blaOCH',
#    'aadA5',
#    'msr(A)',
#    'aadA2b',
#    'erm(A)',
#    'pikR2'],
#   'IncQ_oriT': ['ampC/blaDHA',
#    'vanC2/vanC3',
#    'vgaB',
#    'aadD',
#    'sul2',
#    'erm(B)',
#    'ermX',
#    'erm(D)',
#    'vanRB',
#    'sulA/folP',
#    'tetPB',
#    'apmA',
#    'blaOCH',
#    'aadA5',
#    'msr(A)',
#    'blaCTX-M',
#    'erm(A)',
#    'catB9',
#    'blaLEN',
#    'tetS'],
#   'fosb': ['aac(6)-iw', 'catA3'],
#   'IS26': ['aadE', 'tet39']}}
